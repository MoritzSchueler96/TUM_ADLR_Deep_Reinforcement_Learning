# %% [markdown]
# # Reproduce paper results

# %%
import os
if not 'notebookDir' in globals():
    notebookDir = os.getcwd()
print('notebookDir: ' + notebookDir)
os.chdir(notebookDir)
examples_dir = notebookDir + "/../papers/fixed-wing-gym/gym_fixed_wing/examples/"
print(examples_dir)
# Out:
# notebookDir: /home/user/Documents/Github/Uni/Master/tum-adlr-ws20-08/PyFly101
# /home/user/Documents/Github/Uni/Master/tum-adlr-ws20-08/PyFly101/../papers/fixed-wing-gym/gym_fixed_wing/examples/

# %% [markdown]
# ## Training

# %%
from gym_fixed_wing.examples import train_rl_controller

# %%
os.chdir(examples_dir)
train_rl_controller.main(model_name="test", num_envs=3, disable_curriculum=True, policy="CNN", train_steps=100, test_set_path="test_sets/")
# Out:
# WARNING:tensorflow:From /home/user/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/common/policies.py:940: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-89f6d7dd6d92> in <module>
#       1 os.chdir(examples_dir)
# ----> 2 train_rl_controller.main(model_name="test", num_envs=3, disable_curriculum=True, policy="CNN", train_steps=100, test_set_path="test_sets/")
#
# ~/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/fixed-wing-gym/gym_fixed_wing/examples/train_rl_controller.py in main(model_name, num_envs, env_config_path, train_steps, policy, disable_curriculum, test_set_path)
#     302     else:
#     303         model = PPO2(
# --> 304             policy, env, verbose=1, tensorboard_log=os.path.join(model_folder, "tb")
#     305         )
#     306     model.learn(
#
# ~/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/ppo2/ppo2.py in __init__(self, policy, env, gamma, n_steps, ent_coef, learning_rate, vf_coef, max_grad_norm, lam, nminibatches, noptepochs, cliprange, cliprange_vf, verbose, tensorboard_log, _init_setup_model, policy_kwargs, full_tensorboard_log, seed, n_cpu_tf_sess)
#      96
#      97         if _init_setup_model:
# ---> 98             self.setup_model()
#      99
#     100     def _make_runner(self):
#
# ~/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/ppo2/ppo2.py in setup_model(self)
#     133
#     134                 act_model = self.policy(self.sess, self.observation_space, self.action_space, self.n_envs, 1,
# --> 135                                         n_batch_step, reuse=False, **self.policy_kwargs)
#     136                 with tf.variable_scope("train_model", reuse=True,
#     137                                        custom_getter=tf_util.outer_scope_getter("train_model")):
#
# ~/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/common/policies.py in __init__(self, sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse, **_kwargs)
#    1244             reuse,
#    1245             feature_extraction="cnn_mlp",
# -> 1246             **_kwargs
#    1247         )
#    1248
#
# ~/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/common/policies.py in __init__(self, sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse, layers, net_arch, act_fun, cnn_extractor, feature_extraction, dual_critic, **kwargs)
#     948                         act_fun,
#     949                         dual_critic=dual_critic,
# --> 950                         **kwargs
#     951                     )
#     952                 else:
#
# ~/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/common/policies.py in cnn_mlp_extractor(obs, net_arch, act_fun, obs_module_indices, dual_critic, **kwargs)
#      90     if shared or shared is None:
#      91         name = "shared_c1" if shared is not None else "c1"  # Backwards Compatability
# ---> 92         conv_layer = cnn_1d_extractor(obs, act_fun, name, **kwargs)
#      93         mlps = mlp_extractor(
#      94             conv_layer, net_arch, act_fun, obs_module_indices, dual_critic=dual_critic
#
# ~/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/common/policies.py in cnn_1d_extractor(obs, act_fun, name, **kwargs)
#      77                 stride=1,
#      78                 init_scale=np.sqrt(2),
# ---> 79                 **kwargs
#      80             )
#      81         )
#
# ~/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/common/tf_layers.py in conv(input_tensor, scope, n_filters, filter_size, stride, pad, init_scale, data_format, one_dim_bias)
#      98         raise NotImplementedError
#      99     bias_var_shape = [n_filters] if one_dim_bias else [1, n_filters, 1, 1]
# --> 100     n_input = input_tensor.get_shape()[channel_ax].value
#     101     wshape = [filter_height, filter_width, n_input, n_filters]
#     102     with tf.variable_scope(scope):
#
# ~/miniconda3/envs/adlr/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_shape.py in __getitem__(self, key)
#     868           return self._dims[key].value
#     869         else:
# --> 870           return self._dims[key]
#     871     else:
#     872       if isinstance(key, slice):
#
# IndexError: list index out of range

# %% [markdown]
# ## Evaluation

# %%
from gym_fixed_wing.examples import evaluate_controller
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
os.chdir(examples_dir)
# needed to avoid that multiprocessing creates recursive subprocesses
if __name__ == '__main__':
    evaluate_controller.main(path_to_file="test_sets/test_set_wind_none_step20-20-3.npy", num_envs=4,
    use_pid=True, env_config_path="fixed_wing_config.json", turbulence_intensity="None", print_results=False)
# Out:
# 100/100 scenarios left
# 99/100 scenarios left
# 98/100 scenarios left
# 97/100 scenarios left
# 96/100 scenarios left
# 95/100 scenarios left
# 94/100 scenarios left
# 93/100 scenarios left
# 92/100 scenarios left
# 91/100 scenarios left
# 90/100 scenarios left
# 89/100 scenarios left
# 88/100 scenarios left
# 87/100 scenarios left
# 86/100 scenarios left
# 85/100 scenarios left
# 84/100 scenarios left
# 83/100 scenarios left
# 82/100 scenarios left
# 81/100 scenarios left
# 80/100 scenarios left
# 79/100 scenarios left
# 78/100 scenarios left
# 77/100 scenarios left
# 76/100 scenarios left
# 75/100 scenarios left
# 74/100 scenarios left
# 73/100 scenarios left
# 72/100 scenarios left
# 71/100 scenarios left
# 70/100 scenarios left
# 69/100 scenarios left
# 68/100 scenarios left
# 67/100 scenarios left
# 66/100 scenarios left
# 65/100 scenarios left
# 64/100 scenarios left
# 63/100 scenarios left
# 62/100 scenarios left
# 61/100 scenarios left
# 60/100 scenarios left
# 59/100 scenarios left
# 58/100 scenarios left
# 57/100 scenarios left
# 56/100 scenarios left
# 55/100 scenarios left
# 54/100 scenarios left
# 53/100 scenarios left
# 52/100 scenarios left
# 51/100 scenarios left
# 50/100 scenarios left
# 49/100 scenarios left
# 48/100 scenarios left
# 47/100 scenarios left
# 46/100 scenarios left
# 45/100 scenarios left
# 44/100 scenarios left
# 43/100 scenarios left
# 42/100 scenarios left
# 41/100 scenarios left
# 40/100 scenarios left
# 39/100 scenarios left
# 38/100 scenarios left
# 37/100 scenarios left
# 36/100 scenarios left
# 35/100 scenarios left
# 34/100 scenarios left
# 33/100 scenarios left
# 32/100 scenarios left
# 31/100 scenarios left
# 30/100 scenarios left
# 29/100 scenarios left
# 28/100 scenarios left
# 27/100 scenarios left
# 26/100 scenarios left
# 25/100 scenarios left
# 24/100 scenarios left
# 23/100 scenarios left
# 22/100 scenarios left
# 21/100 scenarios left
# 20/100 scenarios left
# 19/100 scenarios left
# 18/100 scenarios left
# 17/100 scenarios left
# 16/100 scenarios left
# 15/100 scenarios left
# 14/100 scenarios left
# 13/100 scenarios left
# 12/100 scenarios left
# 11/100 scenarios left
# 10/100 scenarios left
# 9/100 scenarios left
# 8/100 scenarios left
# 7/100 scenarios left
# 6/100 scenarios left
# 5/100 scenarios left
# 4/100 scenarios left
# 3/100 scenarios left
# 2/100 scenarios left
# 1/100 scenarios left
# success
# 	roll:	1.0
# 	pitch:	1.0
# 	Va:	1.0
# 	all:	1.0
# control_variation
# 	all:	0.28239413772665256
# rise_time
# 	roll:	133.65591397849462
# 	pitch:	22.6
# 	Va:	101.53571428571429
# overshoot
# 	roll:	0.03491744001110296
# 	pitch:	0.09607746595448735
# 	Va:	0.2892483662133038
# settling_time
# 	roll:	201.72
# 	pitch:	129.36
# 	Va:	220.15
# 	all:	253.46

# %%
os.chdir(examples_dir)
# needed to avoid that multiprocessing creates recursive subprocesses
if __name__ == '__main__':
    evaluate_controller.main(path_to_file="test_sets/test_set_wind_moderate_step20-20-3.npy", num_envs=4, model_path="models/mlp_controller/model.pkl", turbulence_intensity="moderate", print_results=False)
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# WARNING:tensorflow:From /home/user/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/common/policies.py:954: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/user/miniconda3/envs/adlr/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/user/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/user/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/common/distributions.py:452: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /home/user/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/common/distributions.py:154: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/user/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/ppo2/ppo2.py:194: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/user/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/ppo2/ppo2.py:202: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /home/user/miniconda3/envs/adlr/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/user/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/ppo2/ppo2.py:210: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/user/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/ppo2/ppo2.py:244: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /home/user/Documents/Github/Uni/Master/tum-adlr-ws20-08/papers/stable-baselines/stable_baselines/ppo2/ppo2.py:246: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# 100/100 scenarios left
# 99/100 scenarios left
# 98/100 scenarios left
# 97/100 scenarios left
# 96/100 scenarios left
# 95/100 scenarios left
# 94/100 scenarios left
# 93/100 scenarios left
# 92/100 scenarios left
# 91/100 scenarios left
# 90/100 scenarios left
# 89/100 scenarios left
# 88/100 scenarios left
# 87/100 scenarios left
# 86/100 scenarios left
# 85/100 scenarios left
# 84/100 scenarios left
# 83/100 scenarios left
# 82/100 scenarios left
# 81/100 scenarios left
# 80/100 scenarios left
# 79/100 scenarios left
# 78/100 scenarios left
# 77/100 scenarios left
# 76/100 scenarios left
# 75/100 scenarios left
# 74/100 scenarios left
# 73/100 scenarios left
# 72/100 scenarios left
# 71/100 scenarios left
# 70/100 scenarios left
# 69/100 scenarios left
# 68/100 scenarios left
# 67/100 scenarios left
# 66/100 scenarios left
# 65/100 scenarios left
# 64/100 scenarios left
# 63/100 scenarios left
# 62/100 scenarios left
# 61/100 scenarios left
# 60/100 scenarios left
# 59/100 scenarios left
# 58/100 scenarios left
# 57/100 scenarios left
# 56/100 scenarios left
# 55/100 scenarios left
# 54/100 scenarios left
# 53/100 scenarios left
# 52/100 scenarios left
# 51/100 scenarios left
# 50/100 scenarios left
# 49/100 scenarios left
# 48/100 scenarios left
# 47/100 scenarios left
# 46/100 scenarios left
# 45/100 scenarios left
# 44/100 scenarios left
# 43/100 scenarios left
# 42/100 scenarios left
# 41/100 scenarios left
# 40/100 scenarios left
# 39/100 scenarios left
# 38/100 scenarios left
# 37/100 scenarios left
# 36/100 scenarios left
# 35/100 scenarios left
# 34/100 scenarios left
# 33/100 scenarios left
# 32/100 scenarios left
# 31/100 scenarios left
# 30/100 scenarios left
# 29/100 scenarios left
# 28/100 scenarios left
# 27/100 scenarios left
# 26/100 scenarios left
# 25/100 scenarios left
# 24/100 scenarios left
# 23/100 scenarios left
# 22/100 scenarios left
# 21/100 scenarios left
# 20/100 scenarios left
# 19/100 scenarios left
# 18/100 scenarios left
# 17/100 scenarios left
# 16/100 scenarios left
# 15/100 scenarios left
# 14/100 scenarios left
# 13/100 scenarios left
# 12/100 scenarios left
# 11/100 scenarios left
# 10/100 scenarios left
# 9/100 scenarios left
# 8/100 scenarios left
# 7/100 scenarios left
# 6/100 scenarios left
# 5/100 scenarios left
# 4/100 scenarios left
# 3/100 scenarios left
# 2/100 scenarios left
# 1/100 scenarios left
# success
# 	roll:	0.98
# 	pitch:	0.97
# 	Va:	0.97
# 	all:	0.97
# control_variation
# 	all:	1.2784630598842677
# rise_time
# 	roll:	89.02150537634408
# 	pitch:	67.97872340425532
# 	Va:	64.30909090909091
# overshoot
# 	roll:	0.45834825782375777
# 	pitch:	0.5213400202716104
# 	Va:	0.9096450456948966
# settling_time
# 	roll:	279.88659793814435
# 	pitch:	292.6701030927835
# 	Va:	366.03092783505156
# 	all:	385.7319587628866

# %%
# load latest evaluation result
os.chdir(examples_dir)
res = np.load("eval_res.npy", allow_pickle=True).item()
res
# Out:
# .005963609749055776,
#    -0.005767183773889881,
#    -0.005371766586808751,
#    -0.0053502749223606535,
#    -0.004856293181532467,
#    -0.0046000285454838785,
#    -0.0048172750901776815,
#    -0.004392209027896423,
#    -0.004560031776081645,
#    -0.004130859962953569,
#    -0.003897121897023065,
#    -0.003575507330998284,
#    -0.003594861312616618,
#    -0.0032302702622277425,
#    -0.0029878850445452187,
#    -0.0028912899973443326,
#    -0.00250638652004651,
#    -0.0023680624724816226,
#    -0.0025028551282586043,
#    -0.0021831833542872788,
#    -0.002486036289309416,
#    -0.002030539388814137,
#    -0.0024752280866462664,
#    -0.0026452884118306173,
#    -0.0023818905328163403,
#    -0.002273298183558411,
#    -0.002131116944337054,
#    -0.0020407079433097117,
#    -0.0021737079909020813,
#    -0.0018604493347739023,
#    -0.0020611342674804398,
#    -0.0019090765321166175,
#    -0.0016725958799148905,
#    -0.0016106012384758809,
#    -0.0017256710314049828,
#    -0.001616461076382881,
#    -0.0017852983829950296,
#    -0.001921080617407886,
#    -0.0020541394240371673,
#    -0.0022248683352010675,
#    -0.002457270019900721,
#    -0.002303460883290459,
#    -0.002406761835245178,
#    -0.002636475602883324,
#    -0.0026800637783590945,
#    -0.002744073347979687,
#    -0.002758768666866232,
#    -0.0028897458895126658,
#    -0.0028658524634185283,
#    -0.003146818037144981,
#    -0.003105480603519348,
#    -0.003222520032649501,
#    -0.003424851393941158,
#    -0.003214817746512133,
#    -0.0033465236293321182,
#    -0.0034489425104697793,
#    -0.003670243835119912,
#    -0.003848667125494193,
#    -0.00371788690347138,
#    -0.00358423799454894,
#    -0.0038050099817046276,
#    -0.003525597861842952,
#    -0.004023437100638678,
#    -0.0035666711005347056,
#    -0.003668739975232538,
#    -0.0039010142941394146,
#    -0.0037274614290622723,
#    -0.0038023011068336054,
#    -0.0035756043215001807,
#    -0.0036904181236860943,
#    -0.0035918929709598656,
#    -0.0036637885185549176,
#    -0.003442159274986551,
#    -0.0033475170883208857,
#    -0.0035938180300070163,
#    -0.0034821293302870152,
#    -0.00325029597014269,
#    -0.003306072923933472,
#    -0.0034749583675149375,
#    -0.003357589556742474,
#    -0.0032594077660644586,
#    -0.003041325206660264,
#    -0.0028490177787235003,
#    -0.0031402963069670034,
#    -0.0030777668437176123,
#    -0.003199072329458879,
#    -0.0028451339218044168,
#    -0.0026829353965412374,
#    -0.0029112824248798243,
#    -0.002339923870743546,
#    -0.0025605768935241077,
#    -0.0025211102748245243,
#    -0.0026908576771086366,
#    -0.002451060234148077,
#    -0.0022800005256319923,
#    -0.0020319577608373354,
#    -0.002100913478810518,
#    -0.0023013980594411526,
#    -0.0019371500734437577,
#    -0.002031372545745014,
#    -0.0017025462091214212,
#    -0.001795527619213709,
#    -0.0017862355180836055,
#    -0.0016994586640997175,
#    -0.001771720490686076,
#    -0.0015932774991152254],
#   [-0.019136303324438414,
#    -0.019972560482084716,
#    -0.01997304431305411,
#    -0.01966537221523286,
#    -0.019904918304141338,
#    -0.01885068957666718,
#    -0.018685591363932233,
#    -0.01873381180365545,
#    -0.018971470415212764,
#    -0.018591047870516002,
#    -0.018462615227191934,
#    -0.018613221378104335,
#    -0.01854265413427991,
#    -0.018242171392586392,
#    -0.018487206029962067,
#    -0.01818522976806421,
#    -0.01816757236251812,
#    -0.01789208872032955,
#    -0.01763041670474933,
#    -0.017445899073115945,
#    -0.017357347187723804,
#    -0.01717533285012113,
#    -0.01696343836401988,
#    -0.016643954154530446,
#    -0.016142253459339485,
#    -0.01589338383517078,
#    -0.015693434731710698,
#    -0.015468578443802132,
#    -0.015290914587033373,
#    -0.015221543441518126,
#    -0.015120438995212461,
#    -0.015271080618784122,
#    -0.014947708623506955,
#    -0.014941143616050001,
#    -0.014912874615343305,
#    -0.01451229041246347,
#    -0.014515017244767057,
#    -0.014356488962884583,
#    -0.014272490933693562,
#    -0.013936551517949978,
#    -0.01415108453063714,
#    -0.013639207515449852,
#    -0.013412935001704525,
#    -0.013453450456490414,
#    -0.012998881453905122,
#    -0.01270997296307431,
#    -0.01266913733544936,
#    -0.01226129701491382,
#    -0.012082307333127946,
#    -0.011825257256732896,
#    -0.011934214096570998,
#    -0.011558481610340076,
#    -0.011556965002737197,
#    -0.011404101771628454,
#    -0.011084023303717563,
#    -0.010777721889861513,
#    -0.010718751614832787,
#    -0.010506296127984547,
#    -0.010552155182346517,
#    -0.010540310887949187,
#    -0.010241681138785349,
#    -0.01035429334145239,
#    -0.010472890169023471,
#    -0.010455532658200537,
#    -0.010309825294839859,
#    -0.010525214071676359,
#    -0.010324757469675079,
#    -0.010021870992648377,
#    -0.01011073612274238,
#    -0.010032579016269985,
#    -0.01014456785560777,
#    -0.010084448994752644,
#    -0.009826474048718089,
#    -0.009852413727661834,
#    -0.009977811080872272,
#    -0.009985341892152893,
#    -0.009762025583736539,
#    -0.010005712786510246,
#    -0.009951947360385295,
#    -0.010021980581606632,
#    -0.009928054341612542,
#    -0.009611360132604184,
#    -0.009790600552138371,
#    -0.009613418094157595,
#    -0.009819985619591179,
#    -0.00943227665334414,
#    -0.009443634232285728,
#    -0.009525761305905382,
#    -0.009534472024039276,
#    -0.009282903125024548,
#    -0.009449078012419985,
#    -0.00919058614079366,
#    -0.008827932284646319,
#    -0.008897048618120691,
#    -0.008957244789877911,
#    -0.00880569334577241,
#    -0.008954076576896446,
#    -0.009173413714554518,
#    -0.009341087302748447,
#    -0.009706572222457781,
#    -0.009828330569920989,
#    -0.009692865852645697,
#    -0.01002490039565895,
#    -0.010200824329278808,
#    -0.009971466146463194,
#    -0.010094082152376149,
#    -0.010462958699449606,
#    -0.010451037490044566,
#    -0.010719805894140942,
#    -0.010819031173892917,
#    -0.010560621467358507,
#    -0.010944277038549154,
#    -0.010814864562459017,
#    -0.01098178150781156,
#    -0.011083431616087512,
#    -0.010988411885394907,
#    -0.011399856325833676,
#    -0.011192398002187841,
#    -0.011387030080187854,
#    -0.011584342567898231,
#    -0.011221723013087397,
#    -0.011537636228565512,
#    -0.011663440874357337,
#    -0.011560314336626685,
#    -0.011769200934466791,
#    -0.011807359467229491,
#    -0.011924345724890399,
#    -0.011797486405158073,
#    -0.011623376749442312,
#    -0.01189469393676218,
#    -0.011902326988583359,
#    -0.01193679114014516,
#    -0.011841027454243851,
#    -0.011804842521692045,
#    -0.011768312809913679,
#    -0.011649949748801224,
#    -0.011555010531177903,
#    -0.011581282643929833,
#    -0.011560062602837958,
#    -0.011756467534494948,
#    -0.011597303722806516,
#    -0.011742028999030114,
#    -0.011627222372909259,
#    -0.01135094820355816,
#    -0.011345052611091002,
#    -0.011447756571523,
#    -0.011048479238009336,
#    -0.011131973578789998,
#    -0.011169245176947316,
#    -0.010907154899949588,
#    -0.010891650798423082,
#    -0.010858535079267274,
#    -0.01108073694768142,
#    -0.010565621637187007,
#    -0.010650382001966514,
#    -0.01051662756171832,
#    -0.010631767260978892,
#    -0.010419709161644126,
#    -0.010346486199944112,
#    -0.010137787838857222,
#    -0.010232913305309645,
#    -0.009648547424330078,
#    -0.009786668575773016,
#    -0.009691579849674236,
#    -0.009535829568451249,
#    -0.009354472018917209,
#    -0.009307617492916122,
#    -0.009424072305179684,
#    -0.009170132461528143,
#    -0.0091107667291319,
#    -0.008914912639032189,
#    -0.008908084250371647,
#    -0.00887769165753061,
#    -0.008891277978477623,
#    -0.008633471009077796,
#    -0.008564966960741636,
#    -0.00823819823101865,
#    -0.008150791319814013,
#    -0.008496622778354574,
#    -0.008212079211231998,
#    -0.007963168331301751,
#    -0.007987993730201603,
#    -0.007949266263280285,
#    -0.007643952162527579,
#    -0.007595713916725112,
#    -0.007640311586879911,
#    -0.007629201273107493,
#    -0.007526356210177857,
#    -0.007511728588963785,
#    -0.007357447301917571,
#    -0.006990012893643551,
#    -0.007205674491028259,
#    -0.007429492723612539,
#    -0.007135708232246218,
#    -0.0069728965732058,
#    -0.006889376607847937,
#    -0.007150424945496816,
#    -0.006866391024745753,
#    -0.006984690404701155,
#    -0.006974064148633456,
#    -0.006752063755613652,
#    -0.00657662968505394,
#    -0.006865870264999724,
#    -0.006735748948336802,
#    -0.006423430387987747,
#    -0.006769654190927876,
#    -0.006508090420811528,
#    -0.006737854563334156,
#    -0.006484341331378724,
#    -0.006664876007573206,
#    -0.006413010263102525,
#    -0.006634134034700384,
#    -0.006140654277139522,
#    -0.006166457777011646,
#    -0.006301940123688815,
#    -0.0062172301117315145,
#    -0.006300186442746014,
#    -0.006325373707096135,
#    -0.006268278869389032,
#    -0.006116208369403815,
#    -0.006167754972682574,
#    -0.006102014520176842,
#    -0.005863293991408344,
#    -0.006128473120729632,
#    -0.005898200934108712,
#    -0.006028496233727541,
#    -0.006161999008417553,
#    -0.005861929025161774,
#    -0.00606262777979575,
#    -0.005954765969409429,
#    -0.005915480487542944,
#    -0.005903292215322787,
#    -0.00575891761310506,
#    -0.005660297584150876,
#    -0.006035393611468008,
#    -0.005624341463794664,
#    -0.00531820689240688,
#    -0.005683706620587993,
#    -0.00568036344264999,
#    -0.00559642049905001,
#    -0.0055074101755965225,
#    -0.005185621300673411,
#    -0.0051984202236179606,
#    -0.00554496003004683,
#    -0.005529513273847939,
#    -0.005390691402230625,
#    -0.00504012362633797,
#    -0.0051910269237722415,
#    -0.005122540023453841,
#    -0.0051344993303654475,
#    -0.00494810754055232,
#    -0.004775946771491143,
#    -0.004644675829847404,
#    -0.00480407527737013,
#    -0.004852164875013416,
#    -0.004835027101352147,
#    -0.004718852387190122,
#    -0.004594362527459903,
#    -0.004593146495896252,
#    -0.004708092077535454,
#    -0.004483342716023341,
#    -0.004107640625533248,
#    -0.004468064614455243,
#    -0.004418616988427075,
#    -0.004521082911688125,
#    -0.00462264831975197,
#    -0.004193190498759527,
#    -0.004498202238447101,
#    -0.004416178976854167,
#    -0.004110467414492563,
#    -0.004415233997350627,
#    -0.0041639981827299695,
#    -0.003919896610040404,
#    -0.004025912453302286,
#    -0.0039422760186680035,
#    -0.00394990847371784,
#    -0.003908632769226752,
#    -0.0038663270545022175,
#    -0.004043850748844322,
#    -0.003784538254520173,
#    -0.0038585005086605967,
#    -0.003532297344469539,
#    -0.0037733869944801255,
#    -0.0038163094328901533,
#    -0.003600556571625202,
#    -0.003399126521096915,
#    -0.003583665706538043,
#    -0.003779030046372742,
#    -0.003675438815955975,
#    -0.0035912217142141153,
#    -0.0033169201144754557,
#    -0.0033417139543591287,
#    -0.0033834773444239605,
#    -0.003531718766099057,
#    -0.002947722458356563,
#    -0.003278931209279872,
#    -0.0036216466622146335,
#    -0.0033915498157737014,
#    -0.003152071629614633,
#    -0.0032532406587680598,
#    -0.0031664415272399334,
#    -0.003012092539874854,
#    -0.003137989118761366,
#    -0.0031297813816983234,
#    -0.0031315914544687642,
#    -0.0028265898430996483,
#    -0.002992117860080232,
#    -0.0030002538814266583,
#    -0.002643383123054301,
#    -0.003075967185491759,
#    -0.0028819965073108088,
#    -0.00289946351644387,
#    -0.0028361185344208915,
#    -0.002848845933861723,
#    -0.0031293082282399373,
#    -0.0025575886627692557,
#    -0.0026402940057537604,
#    -0.0032383076037058377,
#    -0.002764863351761368,
#    -0.002931770921704581,
#    -0.002899905043604668,
#    -0.002592215274988881,
#    -0.0027596972658825492,
#    -0.0024225844958773108,
#    -0.002665470829100432,
#    -0.002688228843637318,
#    -0.0022912031151137474,
#    -0.0026733837690974907,
#    -0.002380585477953921,
#    -0.002563676368108239,
#    -0.0025564254896424297,
#    -0.0024335360156854478,
#    -0.0025184105876554196,
#    -0.002365245869626886,
#    -0.0025836085845811004,
#    -0.002305096305730562,
#    -0.002270773777853394,
#    -0.0024217022226543125,
#    -0.002606423745946224,
#    -0.002126555000663556,
#    -0.002351786606877336,
#    -0.0025436439732624333,
#    -0.0022063869519044293,
#    -0.0022392442273952034,
#    -0.0022897935575526135,
#    -0.0021563962815874245,
#    -0.002048762537144364,
#    -0.0022497490613195724,
#    -0.0019967379709979667,
#    -0.0022415396252052364,
#    -0.002270468548421495,
#    -0.019003614841647583,
#    -0.019316577817362922,
#    -0.019632565664589555,
#    -0.01968112505017904,
#    -0.019769647857968545,
#    -0.019874906923279388,
#    -0.019999647610885893,
#    -0.01989832905619033,
#    -0.020030229762248067,
#    -0.020262053242511378,
#    -0.020194752913125096,
#    -0.020023856561285802,
#    -0.020190571298400965,
#    -0.02006154991151597,
#    -0.020133807173507733,
#    -0.019947790871677612,
#    -0.01983741022062633,
#    -0.01971576986470213,
#    -0.019888760790069734,
#    -0.01957193861494924,
#    -0.019555705324140367,
#    -0.019382622635866185,
#    -0.01913874886482369,
#    -0.018991962770215844,
#    -0.01877424818215509,
#    -0.018518548802374607,
#    -0.01867395995010797,
#    -0.01790510283658514,
#    -0.0178204952379995,
#    -0.017667757631203145,
#    -0.01695957419615029,
#    -0.01662727167810206,
#    -0.016523748188168434,
#    -0.01619974478267942,
#    -0.015784332210120485,
#    -0.015090225759021338],
#   [-0.02019295651792087,
#    -0.021109711440618555,
#    -0.020685878758815845,
#    -0.021114312281340884,
#    -0.020880770377328974,
#    -0.01951431053795582,
#    -0.020038647574799364,
#    -0.019792848064999518,
#    -0.019579686759780526,
#    -0.01964132805028267,
#    -0.019613861931663944,
#    -0.01945484522831884,
#    -0.019093279812283658,
#    -0.018931624253460635,
#    -0.018710659229685456,
#    -0.018603363770793448,
#    -0.018888305712143085,
#    -0.018636002758426803,
#    -0.018187472459590657,
#    -0.018139553447179314,
#    -0.017878444746658863,
#    -0.01769658795289692,
#    -0.01713304730899731,
#    -0.017395833061187034,
#    -0.017156582226488245,
#    -0.01669613570382145,
#    -0.01653041288059015,
#    -0.016073571618038084,
#    -0.015893061526843763,
#    -0.015436416148774513,
#    -0.01549541624092061,
#    -0.014968094267439407,
#    -0.014986073294635117,
#    -0.01449067598156805,
#    -0.014517801696472295,
#    -0.013858376675459635,
#    -0.013724269999823766,
#    -0.013496436605955698,
#    -0.013157587670490453,
#    -0.012486108893851402,
#    -0.012182365668490071,
#    -0.011942420519453755,
#    -0.011760106942936277,
#    -0.011662630160108127,
#    -0.011536766227164532,
#    -0.01129385514326789,
#    -0.011308007601919023,
#    -0.011161269076118939,
#    -0.0109845863419372,
#    -0.011014806856988187,
#    -0.010661405011938197,
#    -0.01052241187896053,
#    -0.010384248262910109,
#    -0.01035464262913138,
#    -0.010165086193029582,
#    -0.009816489364829827,
#    -0.009959796517901444,
#    -0.010088447457871363,
#    -0.009329864104740597,
#    -0.009384099641425746,
#    -0.009523172845984234,
#    -0.009137749328573915,
#    -0.009351263732342937,
#    -0.009156500371381812,
#    -0.009006219009094247,
#    -0.008733255811194383,
#    -0.008530140554339335,
#    -0.008654543559475786,
#    -0.008586692939097699,
#    -0.007952734642567126,
#    -0.008400462002262273,
#    -0.007953105708199074,
#    -0.00835680666927654,
#    -0.008296676372282664,
#    -0.008072275491169977,
#    -0.007927697169869435,
#    -0.007899035204210638,
#    -0.007615846684998703,
#    -0.007463332626613545,
#    -0.007280428046238409,
#    -0.0073748486849334535,
#    -0.0075167933011604515,
#    -0.007194562997662308,
#    -0.007549308154366291,
#    -0.00729147562901637,
#    -0.0071593278496411466,
#    -0.00721901036902675,
#    -0.00692525183094381,
#    -0.007082459831716945,
#    -0.006731918633868682,
#    -0.006995234421144971,
#    -0.006816949509514735,
#    -0.007051011309674739,
#    -0.006605373750045833,
#    -0.006565719834759879,
#    -0.006492472586995302,
#    -0.0066125591844702365,
#    -0.006554415052711955,
#    -0.006589974156840639,
#    -0.006021275547621887,
#    -0.006280291089498874,
#    -0.005974590866278245,
#    -0.00611454338719429,
#    -0.005661411072097828,
#    -0.005956792143312925,
#    -0.005878173953572332,
#    -0.005831458125337148,
#    -0.006129709168855542,
#    -0.005839231116733972,
#    -0.006155130662058886,
#    -0.006038701851914876,
#    -0.006097295598379525,
#    -0.006170861910053264,
#    -0.006025065647479308,
#    -0.006064450816607077,
#    -0.006167791658829156,
#    -0.005969662261835573,
#    -0.006141877783486554,
#    -0.006123789980427781,
#    -0.0061567288573677135,
#    -0.006260318783711464,
#    -0.005956455140438179,
#    -0.006220293569010392,
#    -0.0064037009502331925,
#    -0.005961665975759942,
#    -0.006130366080294489,
#    -0.006169815625769911,
#    -0.005748615696589417,
#    -0.005809405976619106,
#    -0.006061243761470866,
#    -0.005933620457468208,
#    -0.00590886768333809,
#    -0.0057476620359905506,
#    -0.0057126378565908005,
#    -0.005857895072780673,
#    -0.005662438802605795,
#    -0.005831782865983954,
#    -0.005777358262804734,
#    -0.005596821854070822,
#    -0.005627409601373733,
#    -0.005441516395778576,
#    -0.005545240609057434,
#    -0.005378323513553314,
#    -0.00549054356697263,
#    -0.005407234961355397,
#    -0.005220456417206368,
#    -0.005239370872500462,
#    -0.0050249940927396975,
#    -0.005093268118859898,
#    -0.005269869151636951,
#    -0.005043193672273192,
#    -0.0048738944151476395,
#    -0.004636355188182024,
#    -0.0050174858896685146,
#    -0.00514065895083714,
#    -0.00477966430821548,
#    -0.005079099083111974,
#    -0.005182396050269711,
#    -0.0045919469704790335,
#    -0.004914383709733293,
#    -0.004385012495732143,
#    -0.004755068227322812,
#    -0.004332294359122369,
#    -0.004673088556553189,
#    -0.004506305116412918,
#    -0.004501106003254889,
#    -0.004095603690575523,
#    -0.0045457707499135455,
#    -0.004146461457929998,
#    -0.004297348897562318,
#    -0.004134400488263559,
#    -0.00401267233010787,
#    -0.0039436562794777094,
#    -0.0037204434805693117,
#    -0.003747021652902866,
#    -0.003877806853166477,
#    -0.0037058167188216986,
#    -0.0037370186994201584,
#    -0.00355449944585579,
#    -0.0035616890121561886,
#    -0.0035675954746638887,
#    -0.003722293589242501,
#    -0.0036453833888056624,
#    -0.00344492026131985,
#    -0.0033028914453148445,
#    -0.003266377965982568,
#    -0.0032648644951166557,
#    -0.0033025614505412084,
#    -0.003103998416399985,
#    -0.002997657654521116,
#    -0.0027159504166765097,
#    -0.0027423756068058547,
#    -0.002940830939666539,
#    -0.00298624629748407,
#    -0.0028515268573470493,
#    -0.0026006606879849423,
#    -0.0026253371749178733,
#    -0.0027842323496889876,
#    -0.002733664172140159,
#    -0.002517353188464596,
#    -0.002591651121966683,
#    -0.002728034236445519,
#    -0.00229444131193255,
#    -0.0024615257947841022,
#    -0.002580813770517875,
#    -0.0023002216677550985,
#    -0.0022578018669540444,
#    -0.002254438280365678,
#    -0.002190042125099095,
#    -0.0022159857432401788,
#    -0.002332388643857906,
#    -0.0022159283059991304,
#    -0.0019626482304320875,
#    -0.001882540168197914,
#    -0.0018120061956493955,
#    -0.0019767531888024333,
#    -0.001953435953361514,
#    -0.0019029469255965742,
#    -0.001803898027482073,
#    -0.0019695308535990588,
#    -0.0018734503469430958,
#    -0.0017892681044842033,
#    -0.002097140418738158,
#    -0.0018054300517175454,
#    -0.001970520225417423,
#    -0.0019644879062850553,
#    -0.0014265346352801912,
#    -0.001833208230148743,
#    -0.0015120182848940256,
#    -0.0017507217792573503,
#    -0.0018065681499415953,
#    -0.0018118998692519903,
#    -0.001408705842772447,
#    -0.0015463716195390973,
#    -0.001383904631688647,
#    -0.001473698883417969,
#    -0.001275340362217088,
#    -0.0016358126585149292,
#    -0.0014051505038533147,
#    -0.0013362332814307511,
#    -0.0013156670828983357,
#    -0.0013199827068011657,
#    -0.001430404148597788,
#    -0.0012985907185406515,
#    -0.0010855258355820473,
#    -0.0012867311991732512,
#    -0.0009948364246051865,
#    -0.0011535673024455283,
#    -0.0008335856326164684,
#    -0.0010942153365040427,
#    -0.0011428643130774975,
#    -0.0013543597375141713,
#    -0.0013020990223472138,
#    -0.0010718902912189936,
#    -0.001091287654430859,
#    -0.0010361579888396523,
#    -0.0010214706036195905,
#    -0.0007891597882565629,
#    -0.0010945355791678781,
#    -0.0010205066709003086,
#    -0.0007822248417651946,
#    -0.0009672050579565151,
#    -0.0007389358958582959,
#    -0.0008087654474162204,
#    -0.0009458498625841518,
#    -0.0005700142002834776,
#    -0.0008386685808315981,
#    -0.0008356689920649628,
#    -0.0007333305121986369,
#    -0.001031419072813384,
#    -0.0007432348385044867,
#    -0.0008484375592785546,
#    -0.028238009429018694]]}

# %% [markdown]
# # Information from Readme

# %% [markdown]
# ### Evaluating controllers
# The test_sets folder contains the four test sets used in the paper. Controllers can be evaluated on these sets by doing e.g.:

# %% [markdown]
# first cd into the directory: papers/fixed-wing-gym/gym_fixed_wing/examples/

# %%
python evaluate_controller.py test_sets/test_set_wind_none_step20-20-3.npy --num-envs 4 --PID --env-config-path fixed_wing_config.json --turbulence-intensity "none"
# Out:
#   File "<ipython-input-1-7586b853f429>", line 1
#     python evaluate_controller.py test_sets/test_set_wind_none_step20-20-3.npy --num-envs 4 --PID --env-config-path fixed_wing_config.json --turbulence-intensity "none"
#                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# Or:

# %%
python evaluate_controller.py test_sets/test_set_wind_moderate_step20-20-3.npy --num-envs 4 --model-path models/mlp_controller/model.pkl --turbulence-intensity "moderate"

# %% [markdown]
# Which will evaluate the PID controller on the test set with no wind or turbulence and the MLP controller on the moderate turbulence set, respectively. The model folder contains the CNN RL controller used in the paper, as well as an MLP RL controller usable with the default version of stable-baselines.
# The outputs of the evaluation scripts can be found in the evaluations folder. They are in numpy format and contain the result dictionary, to process them in python do:

# %%
res = np.load("eval_res.npy", allow_pickle=True).item()

# %% [markdown]
# Evaluation results can also be outputted by supplying the evaluation results file path in place of the test set path along with the --print-results flag:

# %%
python evaluate_controller.py evaluations/eval_res_RL_CNN_severe.npy --print-results

# %% [markdown]
# ### Training controllers
#
# To train a reinforcement learning controller, run the train_rl_controller.py script, e.g. to train an agent using 4 processes for 5 million time steps and evaluate on the no turbulence test set, do:

# %%
python train_rl_controller.py "ppo_example" 4 --test-set-path test_sets/test_set_wind_none_step20-20-3.npy

# %% [markdown]
# This script trains a PPO agent to do attitude control of a fixed-wing aircraft. It saves checkpoints of models, renders episodes
#  during training so that its behavior can be inspected, runs periodic test set evaluations if a test set path is supplied, and logs
#  all training information to tensorboard such that its progress can be monitored.

# %%
tensorboard --logdir models/ppo_example/tb

# %% [markdown]
# ![tensorboard log](../papers/fixed-wing-gym/gym_fixed_wing/examples/tensorboard.png)
