# %%
import gym

from stable_baselines3 import PPO
from stable_baselines3 import SAC
from stable_baselines3 import mSAC
from stable_baselines3.common.evaluation import evaluate_policy, evaluate_meta_policy

import numpy as np
from gym import spaces

##pyfly stuff
from pyfly.pyfly import PyFly
from pyfly.pid_controller import PIDController
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation

# %%
#export 
class simrecorder:
   
    
    class prog():
        '''
        Progressbar class. Used for displaying the progress during simulation and rendering. Requires tqdm.
        '''
        def __init__(self,max_it, name, unit, pos):
            from tqdm.notebook import tqdm
            self.bar = tqdm(total=max_it, position=pos, leave=True, unit=unit, desc=name)
            
        def update(self,val):
            self.bar.update(val)
            
        def disable(self):
            self.bar.disable=True
    
    def __init__(self, simduration):
        '''
        Initialize main class, used for recording, plotting
        '''
        self.simduration = simduration # In sim.dt steps
        self.simpb = self.prog(simduration,'Simulating',' Step',0) # progressbar for simulation
    
        ## Arrays used for storing simulation results
        self.res_n = np.zeros(simduration)
        self.res_e = np.zeros(simduration)
        self.res_d = np.zeros(simduration)
        self.roll = np.zeros(simduration)
        self.pitch = np.zeros(simduration)
        self.yaw = np.zeros(simduration)
        self.ran = False
    
    def savestate(self, state, idd):
        '''
        This function is called every step of the simulation 
        and passed simulation object as well as the current simulation step
        '''
#        self.res_n[idd] = state['position_n'].value
#        self.res_e[idd] = state['position_e'].value
#        self.res_d[idd] = -state['position_d'].value
#        self.roll[idd] = state['roll'].value
#        self.pitch[idd] = state['pitch'].value
#        self.yaw[idd] = state['yaw'].value
        if self.ran == False:
            self.ran= True
        
        self.simpb.update(1) # Update progressbar
        
    def read_obj(self, filename):
        '''
        from https://gist.github.com/yzhong52/7c3e0b3a201af45f0cd12f10e06b9d95
        load a .obj file into triangles and vertices
        '''
        triangles = []
        vertices = []
        with open(filename) as file:
            for line in file:
                components = line.strip(' \n').split(' ')
                if components[0] == "f": # face data
                    # e.g. "f 1/1/1/ 2/2/2 3/3/3 4/4/4 ..."
                    indices = list(map(lambda c: int(c.split('/')[0]) - 1, components[1:]))
                    for i in range(0, len(indices) - 2):
                        triangles.append(indices[i: i+3])
                elif components[0] == "v": # vertex data
                    # e.g. "v  30.2180 89.5757 -76.8089"
                    vertex = list(map(lambda c: float(c), components[1:]))
                    vertices.append(vertex)
        return np.array(vertices), np.array(triangles)

    
    
    def rotation_matrix(self, axis, theta):
        import math
        import numpy as np
        """
        Return the rotation matrix associated with counterclockwise rotation about
        the given axis by theta radians.
        """
        axis = np.asarray(axis)
        axis = axis / math.sqrt(np.dot(axis, axis))
        a = math.cos(theta / 2.0)
        b, c, d = -axis * math.sin(theta / 2.0)
        aa, bb, cc, dd = a * a, b * b, c * c, d * d
        bc, ad, ac, ab, bd, cd = b * c, a * d, a * c, a * b, b * d, c * d
        return np.array([[aa + bb - cc - dd, 2 * (bc + ad), 2 * (bd - ac)],
                         [2 * (bc - ad), aa + cc - bb - dd, 2 * (cd + ab)],
                         [2 * (bd + ac), 2 * (cd - ab), aa + dd - bb - cc]])
    
    
        
    def plot(self, rotate=180, interval = 10):
        '''
        Main plotting functions accepting the following optional parameters:
            - rotate: azimuth rotation of final 3D plot.
            - interval: 
        '''
        from IPython.core.display import HTML
        import matplotlib.pyplot as plt
        import mpl_toolkits.mplot3d.axes3d as p3
        import matplotlib.animation as animation        
        
        
        self.fig = plt.figure(figsize=(10,10))
        self.fig.suptitle('')
        
        data = [self.res_n, self.res_e, self.res_d]

        # 
        # top left plot
        ax1 = self.fig.add_subplot(2, 2, 1)
        ax1.set_xlim([np.min(self.res_n)-2,np.max(self.res_n)+2])
        ax1.set_xlabel('X')
        ax1.set_ylim([np.min(self.res_e)-2,np.max(self.res_e)+2])
        ax1.set_ylabel('Y')

        # top right plot
        ax2 = self.fig.add_subplot(2, 2, 2)
        ax2.set_xlim([np.min(self.res_n)-2,np.max(self.res_n)+2])
        ax2.set_xlabel('X')
        ax2.set_ylim([np.min(self.res_d)-2,np.max(self.res_d)+2])
        ax2.set_ylabel('Z')

        # bottom left plot
        self.ax = self.fig.add_subplot(2, 2, 3, projection='3d') #TODO: self needed here (see update_lines)?
        self.ax.set_xlim3d([np.min(data)-2,np.max(data)+2])
        self.ax.set_xlabel('X')
        self.ax.set_ylim3d([np.min(data)-2,np.max(data)+2])
        self.ax.set_ylabel('Y')
        self.ax.set_zlim3d([np.min(data)-2,np.max(data)+2])
        self.ax.set_zlabel('Z')
        
        # bottom right plot
        ax3 = self.fig.add_subplot(2, 2, 4)
        ax3.set_xlim([np.min(self.res_e)-2,np.max(self.res_e)+2])
        ax3.set_xlabel('Y')
        ax3.set_ylim([np.min(self.res_d)-2,np.max(self.res_d)+2])
        ax3.set_ylabel('Z')

        self.ax.set_title('')  #TODO: self needed here (see update_lines)?
        ax1.set_title('') # XY plottitle
        ax2.set_title('') # XZ plottitle
        ax3.set_title('') # YZ plottitle
        
        #l oad drone 3D model
        vertices, self.triangles = self.read_obj("Wing.obj")
        
        # scaling drone 3D model (this is currently at an arbitrary scale)
        self.drone_x = vertices[:,0]*0.15
        self.drone_y = vertices[:,1]*0.15
        self.drone_z = vertices[:,2]*0.15
        
        #Rotate Drone into correct initial orientation
        done = np.dot(self.rotation_matrix([0,0,1], np.pi/2), [self.drone_x,self.drone_y,self.drone_z])
        done = np.dot(self.rotation_matrix([1,0,0], np.pi/2), done)
        [self.drone_x,self.drone_y,self.drone_z] = np.dot(self.rotation_matrix([0,1,0], np.pi), done)
        
        self.drone=[self.drone_x,self.drone_y,self.drone_z]

        


        lines=[0,0,0,0]
        
        lines[0], = self.ax.plot(data[0][0:1], data[1][0:1], data[2][0:1])
        lines[1], = ax1.plot([], [], lw=2)
        lines[2], = ax2.plot([], [], lw=2)
        lines[3], = ax3.plot([], [], lw=2)
         

        # Creating the Animation object
        self.pb = self.prog(500, 'Drawing', ' Frame',0)
        anim = animation.FuncAnimation(self.fig, self.update_lines, 500, fargs=(data, lines, rotate),
                                           interval=interval, blit=False)
        
        #HTML(anim.to_html5_video())
        global nummy
        anim.save('vid_'+str(nummy)+'.mp4')
        nummy = nummy +1
        return 0


    
    # Calculates Rotation Matrix given euler angles.
    def eulerAnglesToRotationMatrix(self, theta) :
        import math

        R_x = np.array([[1,         0,                  0                   ],
                        [0,         math.cos(theta[0]), -math.sin(theta[0]) ],
                        [0,         math.sin(theta[0]), math.cos(theta[0])  ]
                        ])



        R_y = np.array([[math.cos(theta[1]),    0,      math.sin(theta[1])  ],
                        [0,                     1,      0                   ],
                        [-math.sin(theta[1]),   0,      math.cos(theta[1])  ]
                        ])

        R_z = np.array([[math.cos(theta[2]),    -math.sin(theta[2]),    0],
                        [math.sin(theta[2]),    math.cos(theta[2]),     0],
                        [0,                     0,                      1]
                        ])


        R = np.dot(R_z, np.dot( R_y, R_x ))

        return R
    
    
    def update_lines(self, num, dataLines, lines, rotate):
        self.pb.update(1)

        cnt = 0

        for line in lines:
            # NOTE: there is no .set_data() for 3 dim data...
            if str(type(line)) == '''<class 'matplotlib.lines.Line2D'>''':
                if cnt == 0:
                    line.set_data(dataLines[0][:num],dataLines[1][:num])
                elif cnt ==1:
                    line.set_data(dataLines[0][:num],dataLines[2][:num])
                else:
                    line.set_data(dataLines[1][:num],dataLines[2][:num])
                cnt = cnt + 1
            else:
                if len(self.ax.collections):
                    self.ax.collections.pop()
                
                line.set_data(dataLines[0][:num],dataLines[1][:num])
            
                line.set_3d_properties(dataLines[2][:num])
                
                ### Here is probably most optimization potential!!##########
                ### Are the signs correct???
                ### are thes euler angles or not???
                
                #yaw_rot = self.rotation_matrix([0,0,1], self.yaw[num])
                #roll_rot = self.rotation_matrix([0,1,0], self.roll[num])
                #pitch_rot = self.rotation_matrix([1,0,0], self.pitch[num])
                
                #drone = np.dot(yaw_rot, self.drone)
                #drone = np.dot(np.dot(roll_rot,yaw_rot), drone)
                #drone = np.dot(np.dot(pitch_rot,np.dot(roll_rot,yaw_rot)), drone)
               
                drone = np.dot(self.eulerAnglesToRotationMatrix([self.roll[num],self.yaw[num],self.pitch[num]]), self.drone)
            
                ##############################################################
                # ax.plot_trisurf(x, z, triangles, y, shade=True, color='white')
                self.ax.plot_trisurf(drone[0]+dataLines[0][num], drone[2]+dataLines[1][num], self.triangles, drone[1]+dataLines[2][num], shade=True, color='red')
                self.ax.view_init(elev=15., azim=45+rotate*num/self.simduration) # 15, 45
                
        return lines

# %%
class FooEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, task={}, n_tasks=2, **kwargs):
        super(FooEnv, self).__init__()
        
        self.reward_range = (0, 200*15)   
        print('you get this shit from oyster:', task, n_tasks, kwargs )
        
        self.action_space = spaces.Box(
          low=np.array([-1, -1, 0]), high=np.array([1,1,1]), dtype=np.float16)    
        
        self.observation_space = spaces.Box(
          low=np.array([-999,-999,-999,-999,-999,-999,-999 ]), high=np.array([999,999,999,999,999,999,999]), dtype=np.float16)
        self.sim = PyFly("/home/user/anaconda3/lib/python3.8/site-packages/pyfly/pyfly_config.json", "/home/user/anaconda3/lib/python3.8/site-packages/pyfly/x8_param.mat")
        self.sim.seed(0)
        self.sim.reset(state={"roll": 0, "pitch": 0, "Wind": 0})
        self.sim.turbulence = False
        self.sim.turbulence_intensity = 'none'
        
        #self.rec = simrecorder(500)
        self.i = 0
        self.pef = 0
        self.reward_sum = 0
        self.start_height = self.sim.state["position_d"].value
        self.hgtm1 = self.sim.state["position_d"].value
        print(self.observation_space)
        
        
    def reset_task(self, idx):
        print('###################################################')
        self.sim = PyFly("/home/user/anaconda3/lib/python3.8/site-packages/pyfly/pyfly_config.json", "/home/user/anaconda3/lib/python3.8/site-packages/pyfly/x8_param.mat")
        #self.sim.seed(np.random.randint(100000))
#        self.reset()

        pass
    
    def reset(self):
        print('--reset--')
        #if self.rec.ran:
#            self.sim.render(block=True)
            #if self.pef%3 == 0:
        #self.sim.render(block=True)
#                self.rec.plot()
        self.pef = self.pef+1
        self.reward_sum = 0
        
        self.sim = PyFly("/home/user/anaconda3/lib/python3.8/site-packages/pyfly/pyfly_config.json", "/home/user/anaconda3/lib/python3.8/site-packages/pyfly/x8_param.mat")
        self.sim.seed(0)        
        self.sim.reset(state={"roll": 0, "pitch": 0, "Wind": 0})
        self.sim.turbulence = False
        self.sim.turbulence_intensity = 'none'
        self.start_height = self.sim.state["position_d"].value
        self.hgtm1 = self.sim.state["position_d"].value
        
        self.i = 0
        self.rec = simrecorder(500)

        return self._get_obs()
    
    def _get_obs(self):
        phi = self.sim.state["roll"].value
        theta = self.sim.state["pitch"].value
        Va = self.sim.state["Va"].value
        omega_p = self.sim.state["omega_p"].value
        omega_q = self.sim.state["omega_q"].value
        omega_r = self.sim.state["omega_r"].value
        h = self.sim.state["position_d"].value
        
        #print('obserbvtion requested')
        
        return np.array([[phi,
                           theta,
                           Va,
                           omega_p,
                           omega_q,
                           omega_r,
                           h]])
    
    def step(self, a):
#        print('ACTIOIN:', a)
        if a.shape == (1, 3):
            a = a[0]
        success, step_info = self.sim.step(a)
        
        self.rec.savestate(self.sim.state, self.i)
        self.i += 1
        
        
        #forward_reward = (self.start_height - self.sim.state["position_d"].value)**3
        forward_reward = 20* (self.hgtm1 - self.sim.state["position_d"].value) 
        
#        print(forward_reward,self.start_height,self.sim.state["position_d"].value)
        
        ctrl_cost = 0#0.5 * np.square(a).sum()
#        contact_cost = 0.

        survive_reward = 0
#        print(ctrl_cost)
        done = ( not success ) or self.i >= 500
        reward = forward_reward - ctrl_cost + survive_reward #- #- contact_cost + survive_reward
        
                  
        obs = self._get_obs()
        #print('obs:', obs)
#        print('reward:', reward, 'height: ', -self.sim.state["position_d"].value, 'height gained:', self.start_height - self.sim.state["position_d"].value)
        
        self.reward_sum += reward
    
        if self.i%500 == 0 or done:
            print('total height gained: ', self.start_height - self.sim.state["position_d"].value , 'total reward:', self.reward_sum)
            self.sim.render(block=True)
        self.hgtm1 = self.sim.state["position_d"].value
        return obs, reward, done, dict(
            reward_forward=forward_reward,
            reward_ctrl=-ctrl_cost)
    _goal = np.inf        
    
    
    def close(self):
        self.reset()

# %%
import numpy as np
from gym.envs.mujoco import HalfCheetahEnv as HalfCheetahEnv_

class HalfCheetahEnv(HalfCheetahEnv_):
    def _get_obs(self):
        return np.concatenate([
            self.sim.data.qpos.flat[1:],
            self.sim.data.qvel.flat,
            self.get_body_com("torso").flat,
        ]).astype(np.float32).flatten()

    def viewer_setup(self):
        camera_id = self.model.camera_name2id('track')
        self.viewer.cam.type = 2
        self.viewer.cam.fixedcamid = camera_id
        self.viewer.cam.distance = self.model.stat.extent * 0.35
        # Hide the overlay
        self.viewer._hide_overlay = True

    def render(self, mode='human'):
        if mode == 'rgb_array':
            self._get_viewer().render()
            # window size used for old mujoco-py:
            width, height = 500, 500
            data = self._get_viewer().read_pixels(width, height, depth=False)
            return data
        elif mode == 'human':
            self._get_viewer().render()
            
import numpy as np



class HalfCheetahVelEnv(HalfCheetahEnv):
    """Half-cheetah environment with target velocity, as described in [1]. The
    code is adapted from
    https://github.com/cbfinn/maml_rl/blob/9c8e2ebd741cb0c7b8bf2d040c4caeeb8e06cc95/rllab/envs/mujoco/half_cheetah_env_rand.py
    The half-cheetah follows the dynamics from MuJoCo [2], and receives at each
    time step a reward composed of a control cost and a penalty equal to the
    difference between its current velocity and the target velocity. The tasks
    are generated by sampling the target velocities from the uniform
    distribution on [0, 2].
    [1] Chelsea Finn, Pieter Abbeel, Sergey Levine, "Model-Agnostic
        Meta-Learning for Fast Adaptation of Deep Networks", 2017
        (https://arxiv.org/abs/1703.03400)
    [2] Emanuel Todorov, Tom Erez, Yuval Tassa, "MuJoCo: A physics engine for
        model-based control", 2012
        (https://homes.cs.washington.edu/~todorov/papers/TodorovIROS12.pdf)
    """
    def __init__(self, task={}, n_tasks=30000, randomize_tasks=True):
        self._task = task
        self.tasks = self.sample_tasks(n_tasks)
        self._goal_vel = self.tasks[0].get('velocity', 0.0)
        self._goal = self._goal_vel
        self.i = 0
        super(HalfCheetahVelEnv, self).__init__()

    def step(self, action):
        xposbefore = self.sim.data.qpos[0]
        self.do_simulation(action, self.frame_skip)
        xposafter = self.sim.data.qpos[0]

        forward_vel = (xposafter - xposbefore) / self.dt
        forward_reward = -1.0 * abs(forward_vel - self._goal_vel)
        ctrl_cost = 0.5 * 1e-1 * np.sum(np.square(action))

        observation = self._get_obs()
        reward = forward_reward - ctrl_cost
        if self.i >= 200:
            done = True
            self.i = 0
            print(self._goal_vel)
            del self.tasks[0]
            self._goal_vel = self.tasks[0].get('velocity', 0.0)
            self._goal = self._goal_vel
            
        else:
            done = False
            self.i += 1
        infos = dict(reward_forward=forward_reward,
            reward_ctrl=-ctrl_cost, task=self._task)
        return (observation, reward, done, infos)

    def sample_tasks(self, num_tasks):
        np.random.seed(666)
        print('goal sampled')
        velocities = np.random.uniform(0.0, 3.0, size=(num_tasks,))
        tasks = [{'velocity': velocity} for velocity in velocities]
        return tasks

    def get_all_task_idx(self):
        return range(len(self.tasks))

    def reset_task(self, idx):
        self._task = self.tasks[idx]
        self._goal_vel = self._task['velocity']
        self._goal = self._goal_vel
        self.reset()

# %%
(1e6)/20000
# Out:
# 50.0

# %%
env = HalfCheetahVelEnv(n_tasks = 5000000)#gym.make('BipedalWalker-v3')#FooEnv()#

meta_model = mSAC('MlpPolicy', env, verbose=1,policy_kwargs=dict(net_arch=[300, 300, 300], latent_dim = 5, hidden_sizes=[200,200,200]))#,learning_rate=0.0006)

meta_reward = []
meta_std = []

print('-Start-')
n_eval = 30

meta_model_mean_reward_before, meta_model_std_reward_before = evaluate_meta_policy(meta_model, env, n_eval_episodes=n_eval)
meta_reward.append(meta_model_mean_reward_before)
meta_std.append(meta_model_std_reward_before)



print('##################################Start Learning##################################')
for i in range(100):
    
    meta_model.learn(total_timesteps=20000)#, eval_freq=100, n_eval_episodes=5)
    meta_model_mean_reward, meta_model_std_reward = evaluate_meta_policy(meta_model, env, n_eval_episodes=n_eval)

    meta_reward.append(meta_model_mean_reward)
    meta_std.append(meta_model_std_reward)
    
    
    print('epoch:', i)
    print('meta_reward = ', meta_reward)
    print('meta_std = ', meta_std)
    
env.close()
# Out:
# goal sampled
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# critic with  31
# critic with  31
# critic with  31
# critic with  31
# -Start-
# 2.101311365573504
# 2.5325599285513034
# 2.0295430078128764
# 2.1835741717442243
# 2.8543738723390177
# 0.0381095911043029
# 1.2407630963595704
# 0.1464383814000001
# 0.29978568396363425
# 1.5241989173010195
# 0.6007426180034324
# 2.232462506442291
# 0.5786760091217512
# 2.102534256497944
# 0.8796843176077019
# 2.323438362805766
# 0.015326516291399583
# 0.3385729608951239
# 0.33286101596233997
# 0.7430046860850907
# 0.06970889771671174
# 2.1819634627055073
# 1.0201048258638807
# 0.5925094691789949
# 2.727538778518763
# 2.9350409550453858
# 1.5984076323182648
# 0.7773955481068675
# 1.7514378564759157
# 0.977071958800826
# ##################################Start Learning##################################
# 2.6666979413289273
# 1.8792135802692749
# 2.4566210717334553
# 1.6420362611188852
# -------------------------------------
# | time/              |              |
# |    episodes        | 4            |
# |    fps             | 19           |
# |    time_elapsed    | 41           |
# |    total timesteps | 804          |
# | train/             |              |
# |    KL_loss         | 0.034709208  |
# |    actor_loss      | -10.1        |
# |    avg. z          | -0.007897585 |
# |    avg. z var      | 1.065664     |
# |    critic_loss     | 1.22         |
# |    ent_coef        | 0.787        |
# |    ent_coef_loss   | -2.37        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 803          |
# -------------------------------------
# 1.2501360178009597
# 2.2291415752369064
# 1.1087891426927712
# 0.2254996318415754
# -------------------------------------
# | time/              |              |
# |    episodes        | 8            |
# |    fps             | 19           |
# |    time_elapsed    | 81           |
# |    total timesteps | 1608         |
# | train/             |              |
# |    KL_loss         | 0.06813989   |
# |    actor_loss      | -11          |
# |    avg. z          | -0.013887103 |
# |    avg. z var      | 1.1325958    |
# |    critic_loss     | 1.67         |
# |    ent_coef        | 0.618        |
# |    ent_coef_loss   | -4.78        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 1607         |
# -------------------------------------
# 2.32557893535649
# 0.6582277333282374
# 0.2380263805621009
# 1.4603415646295184
# -------------------------------------
# | time/              |              |
# |    episodes        | 12           |
# |    fps             | 19           |
# |    time_elapsed    | 122          |
# |    total timesteps | 2412         |
# | train/             |              |
# |    KL_loss         | 0.01139919   |
# |    actor_loss      | -9.93        |
# |    avg. z          | -0.011789955 |
# |    avg. z var      | 1.0340132    |
# |    critic_loss     | 1.45         |
# |    ent_coef        | 0.487        |
# |    ent_coef_loss   | -7.03        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 2411         |
# -------------------------------------
# 0.46102170600002057
# 2.4853953997573877
# 0.5741057038139918
# 0.8112268612510524
# -------------------------------------
# | time/              |              |
# |    episodes        | 16           |
# |    fps             | 19           |
# |    time_elapsed    | 161          |
# |    total timesteps | 3216         |
# | train/             |              |
# |    KL_loss         | 0.012248433  |
# |    actor_loss      | -6.74        |
# |    avg. z          | -0.057925694 |
# |    avg. z var      | 0.99706393   |
# |    critic_loss     | 1.68         |
# |    ent_coef        | 0.383        |
# |    ent_coef_loss   | -9.3         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 3215         |
# -------------------------------------
# 1.6831032634053231
# 2.7071411696761807
# 2.5553650252892735
# 1.2542458817585893
# -------------------------------------
# | time/              |              |
# |    episodes        | 20           |
# |    fps             | 19           |
# |    time_elapsed    | 203          |
# |    total timesteps | 4020         |
# | train/             |              |
# |    KL_loss         | 0.0018812367 |
# |    actor_loss      | -3.46        |
# |    avg. z          | 0.012794715  |
# |    avg. z var      | 0.9877777    |
# |    critic_loss     | 1.43         |
# |    ent_coef        | 0.301        |
# |    ent_coef_loss   | -11.8        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 4019         |
# -------------------------------------
# 1.180428805751396
# 0.04866153995232836
# 0.8976401155335794
# 1.0613346561834267
# ------------------------------------
# | time/              |             |
# |    episodes        | 24          |
# |    fps             | 19          |
# |    time_elapsed    | 244         |
# |    total timesteps | 4824        |
# | train/             |             |
# |    KL_loss         | 0.012577143 |
# |    actor_loss      | 0.262       |
# |    avg. z          | -0.0393336  |
# |    avg. z var      | 0.9796168   |
# |    critic_loss     | 1.36        |
# |    ent_coef        | 0.237       |
# |    ent_coef_loss   | -14         |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 4823        |
# ------------------------------------
# 2.680507996203805
# 2.3584097082029567
# 2.314160776967631
# 1.2601645718008434
# ------------------------------------
# | time/              |             |
# |    episodes        | 28          |
# |    fps             | 19          |
# |    time_elapsed    | 285         |
# |    total timesteps | 5628        |
# | train/             |             |
# |    KL_loss         | 0.010660811 |
# |    actor_loss      | 4.12        |
# |    avg. z          | 0.03266378  |
# |    avg. z var      | 0.97666276  |
# |    critic_loss     | 1.47        |
# |    ent_coef        | 0.187       |
# |    ent_coef_loss   | -16         |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 5627        |
# ------------------------------------
# 2.328075413988869
# 1.392924430699321
# 0.5453104971536709
# 2.652076814277307
# --------------------------------------
# | time/              |               |
# |    episodes        | 32            |
# |    fps             | 19            |
# |    time_elapsed    | 325           |
# |    total timesteps | 6432          |
# | train/             |               |
# |    KL_loss         | 0.0069763567  |
# |    actor_loss      | 8.54          |
# |    avg. z          | -0.0049610026 |
# |    avg. z var      | 0.9652942     |
# |    critic_loss     | 1.68          |
# |    ent_coef        | 0.147         |
# |    ent_coef_loss   | -17.9         |
# |    learning_rate   | 0.0003        |
# |    n_updates       | 6431          |
# --------------------------------------
# 2.156376803540253
# 2.0156439003560185
# 0.7696908979150158
# 1.2924054673918308
# --------------------------------------
# | time/              |               |
# |    episodes        | 36            |
# |    fps             | 19            |
# |    time_elapsed    | 365           |
# |    total timesteps | 7236          |
# | train/             |               |
# |    KL_loss         | 0.008400653   |
# |    actor_loss      | 14.2          |
# |    avg. z          | -0.0055711665 |
# |    avg. z var      | 0.9880003     |
# |    critic_loss     | 2             |
# |    ent_coef        | 0.116         |
# |    ent_coef_loss   | -20           |
# |    learning_rate   | 0.0003        |
# |    n_updates       | 7235          |
# --------------------------------------
# 0.049360729401962455
# 0.7049814802034337
# 1.533513933499541
# 0.8760277212357167
# --------------------------------------
# | time/              |               |
# |    episodes        | 40            |
# |    fps             | 19            |
# |    time_elapsed    | 407           |
# |    total timesteps | 8040          |
# | train/             |               |
# |    KL_loss         | 0.014990296   |
# |    actor_loss      | 18.5          |
# |    avg. z          | -0.0020220734 |
# |    avg. z var      | 0.9474596     |
# |    critic_loss     | 2.88          |
# |    ent_coef        | 0.0921        |
# |    ent_coef_loss   | -21.1         |
# |    learning_rate   | 0.0003        |
# |    n_updates       | 8039          |
# --------------------------------------
# 1.5056805243938276
# 1.4948193897339426
# 0.311314572452983
# 1.3393293462574003
# ------------------------------------
# | time/              |             |
# |    episodes        | 44          |
# |    fps             | 19          |
# |    time_elapsed    | 447         |
# |    total timesteps | 8844        |
# | train/             |             |
# |    KL_loss         | 0.02161869  |
# |    actor_loss      | 23.3        |
# |    avg. z          | 0.006773283 |
# |    avg. z var      | 0.94399756  |
# |    critic_loss     | 4.42        |
# |    ent_coef        | 0.0733      |
# |    ent_coef_loss   | -20.6       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 8843        |
# ------------------------------------
# 2.90756750530061
# 2.2154133647125143
# 2.158651823349113
# 2.6791301595028116
# ------------------------------------
# | time/              |             |
# |    episodes        | 48          |
# |    fps             | 19          |
# |    time_elapsed    | 485         |
# |    total timesteps | 9648        |
# | train/             |             |
# |    KL_loss         | 0.04385365  |
# |    actor_loss      | 28.4        |
# |    avg. z          | 0.013132486 |
# |    avg. z var      | 0.87740934  |
# |    critic_loss     | 6.18        |
# |    ent_coef        | 0.0585      |
# |    ent_coef_loss   | -21.8       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 9647        |
# ------------------------------------
# 2.8880240437697964
# 0.591150683530195
# 2.1437698926584905
# 0.4857718178411339
# -------------------------------------
# | time/              |              |
# |    episodes        | 52           |
# |    fps             | 19           |
# |    time_elapsed    | 525          |
# |    total timesteps | 10452        |
# | train/             |              |
# |    KL_loss         | 0.0051292004 |
# |    actor_loss      | 34.2         |
# |    avg. z          | 0.021262068  |
# |    avg. z var      | 0.9609272    |
# |    critic_loss     | 11.2         |
# |    ent_coef        | 0.0465       |
# |    ent_coef_loss   | -24          |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 10451        |
# -------------------------------------
# 2.5987643151761786
# 1.8714607417548308
# 2.8783653705794072
# 1.5724261266481232
# ------------------------------------
# | time/              |             |
# |    episodes        | 56          |
# |    fps             | 19          |
# |    time_elapsed    | 564         |
# |    total timesteps | 11256       |
# | train/             |             |
# |    KL_loss         | 0.04682074  |
# |    actor_loss      | 40.6        |
# |    avg. z          | 0.007328631 |
# |    avg. z var      | 0.88087547  |
# |    critic_loss     | 12.4        |
# |    ent_coef        | 0.0371      |
# |    ent_coef_loss   | -23.7       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 11255       |
# ------------------------------------
# 0.1092986344503043
# 2.1806147356918393
# 0.011729531603332455
# 0.15088200352418113
# -------------------------------------
# | time/              |              |
# |    episodes        | 60           |
# |    fps             | 19           |
# |    time_elapsed    | 603          |
# |    total timesteps | 12060        |
# | train/             |              |
# |    KL_loss         | 0.09254655   |
# |    actor_loss      | 47           |
# |    avg. z          | -0.046902724 |
# |    avg. z var      | 0.94107115   |
# |    critic_loss     | 6.38         |
# |    ent_coef        | 0.0295       |
# |    ent_coef_loss   | -24.9        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 12059        |
# -------------------------------------
# 2.9759769476257127
# 0.636772501044184
# 2.842111994623015
# 1.3546216464300702
# -------------------------------------
# | time/              |              |
# |    episodes        | 64           |
# |    fps             | 19           |
# |    time_elapsed    | 644          |
# |    total timesteps | 12864        |
# | train/             |              |
# |    KL_loss         | 0.01980003   |
# |    actor_loss      | 52.9         |
# |    avg. z          | -0.025500864 |
# |    avg. z var      | 0.9019658    |
# |    critic_loss     | 5.81         |
# |    ent_coef        | 0.0235       |
# |    ent_coef_loss   | -25.7        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 12863        |
# -------------------------------------
# 2.9963840182850765
# 1.9425044674274434
# 2.1067221295739973
# 1.2887452963202946
# ------------------------------------
# | time/              |             |
# |    episodes        | 68          |
# |    fps             | 19          |
# |    time_elapsed    | 683         |
# |    total timesteps | 13668       |
# | train/             |             |
# |    KL_loss         | 0.02827941  |
# |    actor_loss      | 56.9        |
# |    avg. z          | -0.03155423 |
# |    avg. z var      | 0.93205214  |
# |    critic_loss     | 13          |
# |    ent_coef        | 0.0186      |
# |    ent_coef_loss   | -27.1       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 13667       |
# ------------------------------------
# 0.503324279526767
# 0.35439928044071944
# 2.8136478654753763
# 2.732992331423361
# ------------------------------------
# | time/              |             |
# |    episodes        | 72          |
# |    fps             | 20          |
# |    time_elapsed    | 721         |
# |    total timesteps | 14472       |
# | train/             |             |
# |    KL_loss         | 0.03095058  |
# |    actor_loss      | 64.5        |
# |    avg. z          | 0.036485847 |
# |    avg. z var      | 0.88584197  |
# |    critic_loss     | 7.57        |
# |    ent_coef        | 0.0148      |
# |    ent_coef_loss   | -24.6       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 14471       |
# ------------------------------------
# 1.1939806105526265
# 2.775909798093998
# 2.2364976515754886
# 2.3694790933232106
# -------------------------------------
# | time/              |              |
# |    episodes        | 76           |
# |    fps             | 20           |
# |    time_elapsed    | 760          |
# |    total timesteps | 15276        |
# | train/             |              |
# |    KL_loss         | 0.013236333  |
# |    actor_loss      | 67.5         |
# |    avg. z          | -0.033412088 |
# |    avg. z var      | 0.95144033   |
# |    critic_loss     | 13.1         |
# |    ent_coef        | 0.0118       |
# |    ent_coef_loss   | -26.5        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 15275        |
# -------------------------------------
# 1.9131255533997786
# 2.978224099637898
# 1.428316610571466
# 0.3063425574268478
# ------------------------------------
# | time/              |             |
# |    episodes        | 80          |
# |    fps             | 20          |
# |    time_elapsed    | 802         |
# |    total timesteps | 16080       |
# | train/             |             |
# |    KL_loss         | 0.030633591 |
# |    actor_loss      | 74.3        |
# |    avg. z          | 0.014018419 |
# |    avg. z var      | 0.9115735   |
# |    critic_loss     | 19.1        |
# |    ent_coef        | 0.00938     |
# |    ent_coef_loss   | -24         |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 16079       |
# ------------------------------------
# 2.6176899744923516
# 2.2683811315818123
# 0.8975965094267363
# 0.5587695582436537
# ------------------------------------
# | time/              |             |
# |    episodes        | 84          |
# |    fps             | 20          |
# |    time_elapsed    | 841         |
# |    total timesteps | 16884       |
# | train/             |             |
# |    KL_loss         | 0.031827327 |
# |    actor_loss      | 81.6        |
# |    avg. z          | 0.036077686 |
# |    avg. z var      | 0.88531417  |
# |    critic_loss     | 12.1        |
# |    ent_coef        | 0.00737     |
# |    ent_coef_loss   | -32.8       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 16883       |
# ------------------------------------
# 1.483060542767789
# 0.12268649811643662
# 1.435056846434755
# 0.9269705984970229
# ------------------------------------
# | time/              |             |
# |    episodes        | 88          |
# |    fps             | 20          |
# |    time_elapsed    | 880         |
# |    total timesteps | 17688       |
# | train/             |             |
# |    KL_loss         | 0.018027335 |
# |    actor_loss      | 85.5        |
# |    avg. z          | 0.006567247 |
# |    avg. z var      | 0.9404961   |
# |    critic_loss     | 15.7        |
# |    ent_coef        | 0.00576     |
# |    ent_coef_loss   | -33.2       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 17687       |
# ------------------------------------
# 2.761740787460016
# 2.7538370541738777
# 1.4054667940418657
# 0.7029392495557287
# -------------------------------------
# | time/              |              |
# |    episodes        | 92           |
# |    fps             | 20           |
# |    time_elapsed    | 920          |
# |    total timesteps | 18492        |
# | train/             |              |
# |    KL_loss         | 0.06350043   |
# |    actor_loss      | 93           |
# |    avg. z          | -0.011955049 |
# |    avg. z var      | 0.8139229    |
# |    critic_loss     | 41.6         |
# |    ent_coef        | 0.00451      |
# |    ent_coef_loss   | -33          |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 18491        |
# -------------------------------------
# 0.269474830630996
# 2.038210723107573
# 1.9677849667655831
# 0.011833197811942475
# -------------------------------------
# | time/              |              |
# |    episodes        | 96           |
# |    fps             | 20           |
# |    time_elapsed    | 960          |
# |    total timesteps | 19296        |
# | train/             |              |
# |    KL_loss         | 0.042280518  |
# |    actor_loss      | 98.4         |
# |    avg. z          | -0.040304538 |
# |    avg. z var      | 0.84386444   |
# |    critic_loss     | 16.5         |
# |    ent_coef        | 0.00353      |
# |    ent_coef_loss   | -37          |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 19295        |
# -------------------------------------
# 0.19962401770421812
# 0.0033632737069495544
# 1.9982514507114943
# 1.1569534792921967
# 0.28217482121291393
# 1.3757027191077593
# 1.9330251852400004
# 1.784993216877644
# 2.3718092214736695
# 2.3999072075920056
# 2.0390937568347427
# 1.3162555564946936
# 0.7870766782725064
# 0.7095656504682741
# 2.5170062292970337
# 1.1062300170672932
# 1.8575651450430288
# 1.3996929855474842
# 1.4775018925997294
# 2.1558663409130814
# 1.962476440610927
# 2.8995050898642667
# 1.1687170024561682
# 2.9105165761769696
# 1.0817388161230177
# 1.6855270151136512
# 0.0940067340810441
# 0.9144008338455998
# 0.21808395238817257
# 1.4016597767146788
# 1.2403520814143405
# 1.266848136839481
# 2.384730926225715
# epoch: 0
# meta_reward =  [-318.68103072624336]
# meta_std =  [147.71888857471905]
# 0.16955564566443193
# 2.6915460338651442
# 0.9560891262464367
# 1.0919603512237268
# -------------------------------------
# | time/              |              |
# |    episodes        | 4            |
# |    fps             | 20           |
# |    time_elapsed    | 38           |
# |    total timesteps | 804          |
# | train/             |              |
# |    KL_loss         | 0.062081     |
# |    actor_loss      | 111          |
# |    avg. z          | 0.0069673792 |
# |    avg. z var      | 0.82268065   |
# |    critic_loss     | 60.6         |
# |    ent_coef        | 0.00224      |
# |    ent_coef_loss   | -39.8        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 20803        |
# -------------------------------------
# 2.1164641276955516
# 0.6931049094661202
# 1.6448112940059905
# 0.9586805987340445
# ------------------------------------
# | time/              |             |
# |    episodes        | 8           |
# |    fps             | 20          |
# |    time_elapsed    | 76          |
# |    total timesteps | 1608        |
# | train/             |             |
# |    KL_loss         | 0.012946036 |
# |    actor_loss      | 114         |
# |    avg. z          | -0.01767477 |
# |    avg. z var      | 0.9155774   |
# |    critic_loss     | 11.8        |
# |    ent_coef        | 0.00176     |
# |    ent_coef_loss   | -40.7       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 21607       |
# ------------------------------------
# 2.190633902483565
# 2.8277169767982997
# 2.3232675682483928
# 2.5913722978616294
# -------------------------------------
# | time/              |              |
# |    episodes        | 12           |
# |    fps             | 20           |
# |    time_elapsed    | 116          |
# |    total timesteps | 2412         |
# | train/             |              |
# |    KL_loss         | 0.121376455  |
# |    actor_loss      | 119          |
# |    avg. z          | -0.027625933 |
# |    avg. z var      | 0.7280265    |
# |    critic_loss     | 62.2         |
# |    ent_coef        | 0.00139      |
# |    ent_coef_loss   | -36.8        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 22411        |
# -------------------------------------
# 2.4871084556398224
# 2.44138940011951
# 1.8949870150002979
# 2.0643127683354376
# ------------------------------------
# | time/              |             |
# |    episodes        | 16          |
# |    fps             | 20          |
# |    time_elapsed    | 154         |
# |    total timesteps | 3216        |
# | train/             |             |
# |    KL_loss         | 0.039330892 |
# |    actor_loss      | 125         |
# |    avg. z          | 0.016418789 |
# |    avg. z var      | 0.85059834  |
# |    critic_loss     | 15.5        |
# |    ent_coef        | 0.00111     |
# |    ent_coef_loss   | -37.8       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 23215       |
# ------------------------------------
# 0.28516625184252764
# 2.6291181312253036
# 2.4984152489627984
# 1.2620204608315935
# ------------------------------------
# | time/              |             |
# |    episodes        | 20          |
# |    fps             | 20          |
# |    time_elapsed    | 192         |
# |    total timesteps | 4020        |
# | train/             |             |
# |    KL_loss         | 0.041979514 |
# |    actor_loss      | 129         |
# |    avg. z          | 0.008869259 |
# |    avg. z var      | 0.8821408   |
# |    critic_loss     | 129         |
# |    ent_coef        | 0.000888    |
# |    ent_coef_loss   | -36.6       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 24019       |
# ------------------------------------
# 2.327476741659951
# 1.4729337683421369
# 1.57810331178925
# 2.1414520085889754
# ------------------------------------
# | time/              |             |
# |    episodes        | 24          |
# |    fps             | 20          |
# |    time_elapsed    | 232         |
# |    total timesteps | 4824        |
# | train/             |             |
# |    KL_loss         | 0.052936845 |
# |    actor_loss      | 130         |
# |    avg. z          | 0.01830814  |
# |    avg. z var      | 0.84677327  |
# |    critic_loss     | 35.7        |
# |    ent_coef        | 0.000718    |
# |    ent_coef_loss   | -32.9       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 24823       |
# ------------------------------------
# 0.3695171089793605
# 1.3583956392355816
# 0.42408129641569126
# 1.0202280648055104
# -------------------------------------
# | time/              |              |
# |    episodes        | 28           |
# |    fps             | 20           |
# |    time_elapsed    | 273          |
# |    total timesteps | 5628         |
# | train/             |              |
# |    KL_loss         | 0.01942774   |
# |    actor_loss      | 134          |
# |    avg. z          | -0.030010441 |
# |    avg. z var      | 0.91557693   |
# |    critic_loss     | 11.1         |
# |    ent_coef        | 0.000596     |
# |    ent_coef_loss   | -24.9        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 25627        |
# -------------------------------------
# 0.7006364456573632
# 1.522332824567179
# 1.2822441383669687
# 1.6094170912535701
# ------------------------------------
# | time/              |             |
# |    episodes        | 32          |
# |    fps             | 20          |
# |    time_elapsed    | 315         |
# |    total timesteps | 6432        |
# | train/             |             |
# |    KL_loss         | 0.055035993 |
# |    actor_loss      | 139         |
# |    avg. z          | 0.037994545 |
# |    avg. z var      | 0.861626    |
# |    critic_loss     | 18.3        |
# |    ent_coef        | 0.00051     |
# |    ent_coef_loss   | -14         |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 26431       |
# ------------------------------------
# 2.6072525969094773
# 2.530046548436516
# 0.12408200286394822
# 0.2326109844951958
# -----------------------------------
# | time/              |            |
# |    episodes        | 36         |
# |    fps             | 20         |
# |    time_elapsed    | 359        |
# |    total timesteps | 7236       |
# | train/             |            |
# |    KL_loss         | 0.12225248 |
# |    actor_loss      | 142        |
# |    avg. z          | 0.02643539 |
# |    avg. z var      | 0.7474987  |
# |    critic_loss     | 132        |
# |    ent_coef        | 0.000441   |
# |    ent_coef_loss   | -17.1      |
# |    learning_rate   | 0.0003     |
# |    n_updates       | 27235      |
# -----------------------------------
# 1.104015237625228
# 2.2329399579992124
# 1.1653286206579807
# 0.43905275016872436
# --------------------------------------
# | time/              |               |
# |    episodes        | 40            |
# |    fps             | 20            |
# |    time_elapsed    | 399           |
# |    total timesteps | 8040          |
# | train/             |               |
# |    KL_loss         | 0.055467345   |
# |    actor_loss      | 144           |
# |    avg. z          | -0.0049232156 |
# |    avg. z var      | 0.81764203    |
# |    critic_loss     | 128           |
# |    ent_coef        | 0.000386      |
# |    ent_coef_loss   | -10           |
# |    learning_rate   | 0.0003        |
# |    n_updates       | 28039         |
# --------------------------------------
# 1.1319872658387045
# 1.1143883410657538
# 2.7979019349382748
# 2.6361280075847464
# -------------------------------------
# | time/              |              |
# |    episodes        | 44           |
# |    fps             | 20           |
# |    time_elapsed    | 438          |
# |    total timesteps | 8844         |
# | train/             |              |
# |    KL_loss         | 0.039955907  |
# |    actor_loss      | 144          |
# |    avg. z          | -0.019022232 |
# |    avg. z var      | 0.8387195    |
# |    critic_loss     | 94.7         |
# |    ent_coef        | 0.000342     |
# |    ent_coef_loss   | -5.2         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 28843        |
# -------------------------------------
# 1.9062086719690092
# 0.2193354659362543
# 2.541931087800947
# 2.5518968644033015
# ------------------------------------
# | time/              |             |
# |    episodes        | 48          |
# |    fps             | 20          |
# |    time_elapsed    | 480         |
# |    total timesteps | 9648        |
# | train/             |             |
# |    KL_loss         | 0.08751096  |
# |    actor_loss      | 146         |
# |    avg. z          | 0.013887498 |
# |    avg. z var      | 0.7709671   |
# |    critic_loss     | 27.4        |
# |    ent_coef        | 0.000304    |
# |    ent_coef_loss   | -2.45       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 29647       |
# ------------------------------------
# 1.0119074398148329
# 1.9334892920925006
# 2.499078292243455
# 1.6033356612230443
# ------------------------------------
# | time/              |             |
# |    episodes        | 52          |
# |    fps             | 20          |
# |    time_elapsed    | 519         |
# |    total timesteps | 10452       |
# | train/             |             |
# |    KL_loss         | 0.052411176 |
# |    actor_loss      | 149         |
# |    avg. z          | 0.006373009 |
# |    avg. z var      | 0.81771564  |
# |    critic_loss     | 54.9        |
# |    ent_coef        | 0.000262    |
# |    ent_coef_loss   | -12.3       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 30451       |
# ------------------------------------
# 1.9832469387913452
# 1.7723988607520842
# 1.2242040086464003
# 0.689035012701721
# ------------------------------------
# | time/              |             |
# |    episodes        | 56          |
# |    fps             | 20          |
# |    time_elapsed    | 557         |
# |    total timesteps | 11256       |
# | train/             |             |
# |    KL_loss         | 0.059202023 |
# |    actor_loss      | 151         |
# |    avg. z          | 0.002061802 |
# |    avg. z var      | 0.8029337   |
# |    critic_loss     | 186         |
# |    ent_coef        | 0.000215    |
# |    ent_coef_loss   | -8.86       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 31255       |
# ------------------------------------
# 2.0674621651427625
# 2.937889949353407
# 2.5837447495971797
# 2.564120611044956
# --------------------------------------
# | time/              |               |
# |    episodes        | 60            |
# |    fps             | 20            |
# |    time_elapsed    | 597           |
# |    total timesteps | 12060         |
# | train/             |               |
# |    KL_loss         | 0.02396812    |
# |    actor_loss      | 151           |
# |    avg. z          | -0.0095809465 |
# |    avg. z var      | 0.8895397     |
# |    critic_loss     | 15.9          |
# |    ent_coef        | 0.000161      |
# |    ent_coef_loss   | -10.4         |
# |    learning_rate   | 0.0003        |
# |    n_updates       | 32059         |
# --------------------------------------
# 1.6560842838106633
# 1.2709477403194267
# 0.5497736288452165
# 1.2605581697008654
# -------------------------------------
# | time/              |              |
# |    episodes        | 64           |
# |    fps             | 19           |
# |    time_elapsed    | 647          |
# |    total timesteps | 12864        |
# | train/             |              |
# |    KL_loss         | 0.04989232   |
# |    actor_loss      | 153          |
# |    avg. z          | -0.005326631 |
# |    avg. z var      | 0.816061     |
# |    critic_loss     | 107          |
# |    ent_coef        | 0.00013      |
# |    ent_coef_loss   | -13.8        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 32863        |
# -------------------------------------
# 2.0373168913667543
# 0.9687826085553395
# 2.6223021609600266
# 2.4956405187164536
# ------------------------------------
# | time/              |             |
# |    episodes        | 68          |
# |    fps             | 19          |
# |    time_elapsed    | 690         |
# |    total timesteps | 13668       |
# | train/             |             |
# |    KL_loss         | 0.07474868  |
# |    actor_loss      | 156         |
# |    avg. z          | 0.055369996 |
# |    avg. z var      | 0.7989301   |
# |    critic_loss     | 19.5        |
# |    ent_coef        | 9.59e-05    |
# |    ent_coef_loss   | -13         |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 33667       |
# ------------------------------------
# 0.24437773100421067
# 1.8055485624031071
# 2.5968791104910265
# 2.145362566236879
# ---------------------------------------
# | time/              |                |
# |    episodes        | 72             |
# |    fps             | 19             |
# |    time_elapsed    | 732            |
# |    total timesteps | 14472          |
# | train/             |                |
# |    KL_loss         | 0.10701476     |
# |    actor_loss      | 158            |
# |    avg. z          | -0.00037116697 |
# |    avg. z var      | 0.73680377     |
# |    critic_loss     | 15.1           |
# |    ent_coef        | 8.14e-05       |
# |    ent_coef_loss   | -6.73          |
# |    learning_rate   | 0.0003         |
# |    n_updates       | 34471          |
# ---------------------------------------
# 0.26855273302253335
# 2.8696216121223745
# 0.029115859782282927
# 2.469851122104216
# ------------------------------------
# | time/              |             |
# |    episodes        | 76          |
# |    fps             | 19          |
# |    time_elapsed    | 770         |
# |    total timesteps | 15276       |
# | train/             |             |
# |    KL_loss         | 0.05751974  |
# |    actor_loss      | 160         |
# |    avg. z          | -0.04268577 |
# |    avg. z var      | 0.8178514   |
# |    critic_loss     | 18.8        |
# |    ent_coef        | 6.34e-05    |
# |    ent_coef_loss   | -20.2       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 35275       |
# ------------------------------------
# 1.5584510708252495
# 0.35346503382273275
# 1.585914265076969
# 2.0110831693405533
# ------------------------------------
# | time/              |             |
# |    episodes        | 80          |
# |    fps             | 19          |
# |    time_elapsed    | 808         |
# |    total timesteps | 16080       |
# | train/             |             |
# |    KL_loss         | 0.09891799  |
# |    actor_loss      | 163         |
# |    avg. z          | 0.007806842 |
# |    avg. z var      | 0.7610614   |
# |    critic_loss     | 106         |
# |    ent_coef        | 4.99e-05    |
# |    ent_coef_loss   | -6.83       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 36079       |
# ------------------------------------
# 0.7006576676094968
# 1.9800183986278679
# 0.3495403523238795
# 1.1490587887365842
# --------------------------------------
# | time/              |               |
# |    episodes        | 84            |
# |    fps             | 19            |
# |    time_elapsed    | 848           |
# |    total timesteps | 16884         |
# | train/             |               |
# |    KL_loss         | 0.026997425   |
# |    actor_loss      | 162           |
# |    avg. z          | -0.0015123992 |
# |    avg. z var      | 0.8646695     |
# |    critic_loss     | 15.7          |
# |    ent_coef        | 4.34e-05      |
# |    ent_coef_loss   | -10.6         |
# |    learning_rate   | 0.0003        |
# |    n_updates       | 36883         |
# --------------------------------------
# 1.8729424445065357
# 0.8835205329475305
# 0.44490033026746567
# 0.7069052031957267
# -------------------------------------
# | time/              |              |
# |    episodes        | 88           |
# |    fps             | 19           |
# |    time_elapsed    | 887          |
# |    total timesteps | 17688        |
# | train/             |              |
# |    KL_loss         | 0.038055085  |
# |    actor_loss      | 160          |
# |    avg. z          | -0.017346073 |
# |    avg. z var      | 0.8413135    |
# |    critic_loss     | 25.3         |
# |    ent_coef        | 3.69e-05     |
# |    ent_coef_loss   | -1.21        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 37687        |
# -------------------------------------
# 1.6923060982589693
# 2.7629081443327848
# 2.169533340464194
# 2.860731415629016
# -------------------------------------
# | time/              |              |
# |    episodes        | 92           |
# |    fps             | 19           |
# |    time_elapsed    | 925          |
# |    total timesteps | 18492        |
# | train/             |              |
# |    KL_loss         | 0.051447667  |
# |    actor_loss      | 162          |
# |    avg. z          | -0.019664612 |
# |    avg. z var      | 0.81797063   |
# |    critic_loss     | 26           |
# |    ent_coef        | 3.85e-05     |
# |    ent_coef_loss   | 5.59         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 38491        |
# -------------------------------------
# 0.7679958041416519
# 1.931167939181293
# 1.0815860907931105
# 1.2629416688910837
# --------------------------------------
# | time/              |               |
# |    episodes        | 96            |
# |    fps             | 19            |
# |    time_elapsed    | 967           |
# |    total timesteps | 19296         |
# | train/             |               |
# |    KL_loss         | 0.06928317    |
# |    actor_loss      | 163           |
# |    avg. z          | -0.0075240955 |
# |    avg. z var      | 0.78498715    |
# |    critic_loss     | 13.9          |
# |    ent_coef        | 4.52e-05      |
# |    ent_coef_loss   | 4.61          |
# |    learning_rate   | 0.0003        |
# |    n_updates       | 39295         |
# --------------------------------------
# 1.2574137272405772
# 0.9716371592663012
# 2.4602310856265817
# 1.4875810776984004
# 2.815217822014504
# 0.783119577787672
# 1.3947408058463937
# 2.7412745211732585
# 0.297376730546703
# 1.9387133526442564
# 1.2627852145968723
# 1.7038313916292678
# 2.5393719057769917
# 0.5141361565983843
# 1.9283460227841658
# 0.17449384114993616
# 0.5217741947582547
# 2.402581670689946
# 2.9257326520741906
# 2.7529255474280636
# 2.79025153394381
# 2.6827604321055927
# 0.7905945028154093
# 1.4976905764304775
# 1.3833471568593163
# 0.8465035742007541
# 1.864085126686024
# 0.051000026098995344
# 2.647603405922065
# 0.43979630962755956
# 1.2007553486505795
# 1.8484743894781897
# 1.7645459899158937
# epoch: 1
# meta_reward =  [-318.68103072624336, -326.54882258410385]
# meta_std =  [147.71888857471905, 175.5345762966199]
# 0.1621324847471497
# 2.2604654917044433
# 1.6472265152652559
# 1.6813609721498084
# -------------------------------------
# | time/              |              |
# |    episodes        | 4            |
# |    fps             | 21           |
# |    time_elapsed    | 37           |
# |    total timesteps | 804          |
# | train/             |              |
# |    KL_loss         | 0.014975119  |
# |    actor_loss      | 161          |
# |    avg. z          | -0.004066596 |
# |    avg. z var      | 0.91272753   |
# |    critic_loss     | 125          |
# |    ent_coef        | 7.4e-05      |
# |    ent_coef_loss   | 1.96         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 40803        |
# -------------------------------------
# 2.301316509644411
# 0.632366915250476
# 2.921026505619125
# 1.5231580982999993
# -----------------------------------
# | time/              |            |
# |    episodes        | 8          |
# |    fps             | 20         |
# |    time_elapsed    | 80         |
# |    total timesteps | 1608       |
# | train/             |            |
# |    KL_loss         | 0.02499057 |
# |    actor_loss      | 162        |
# |    avg. z          | 0.01413884 |
# |    avg. z var      | 0.88170844 |
# |    critic_loss     | 18.8       |
# |    ent_coef        | 8.65e-05   |
# |    ent_coef_loss   | 14.9       |
# |    learning_rate   | 0.0003     |
# |    n_updates       | 41607      |
# -----------------------------------
# 1.472936657138765
# 2.54759735789048
# 0.9496296501596828
# 2.39458088096442
# -------------------------------------
# | time/              |              |
# |    episodes        | 12           |
# |    fps             | 20           |
# |    time_elapsed    | 118          |
# |    total timesteps | 2412         |
# | train/             |              |
# |    KL_loss         | 0.030564494  |
# |    actor_loss      | 164          |
# |    avg. z          | -0.031787593 |
# |    avg. z var      | 0.8629882    |
# |    critic_loss     | 99           |
# |    ent_coef        | 9.81e-05     |
# |    ent_coef_loss   | 15.1         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 42411        |
# -------------------------------------
# 0.6268470219669741
# 0.024848774231004622
# 1.9478475390804353
# 2.348622792644991
# -------------------------------------
# | time/              |              |
# |    episodes        | 16           |
# |    fps             | 20           |
# |    time_elapsed    | 157          |
# |    total timesteps | 3216         |
# | train/             |              |
# |    KL_loss         | 0.013255581  |
# |    actor_loss      | 161          |
# |    avg. z          | 0.0036098647 |
# |    avg. z var      | 0.9199489    |
# |    critic_loss     | 72.9         |
# |    ent_coef        | 0.000119     |
# |    ent_coef_loss   | 3.05         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 43215        |
# -------------------------------------
# 0.3180148029673945
# 1.3190644691028195
# 0.27500904575806195
# 0.637074212790489
# ------------------------------------
# | time/              |             |
# |    episodes        | 20          |
# |    fps             | 20          |
# |    time_elapsed    | 199         |
# |    total timesteps | 4020        |
# | train/             |             |
# |    KL_loss         | 0.08946255  |
# |    actor_loss      | 163         |
# |    avg. z          | 0.018985957 |
# |    avg. z var      | 0.75940293  |
# |    critic_loss     | 20.3        |
# |    ent_coef        | 0.000146    |
# |    ent_coef_loss   | 4.67        |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 44019       |
# ------------------------------------
# 1.9451284765131451
# 1.8053904342370652
# 1.4052608939516915
# 0.38879223589091383
# -------------------------------------
# | time/              |              |
# |    episodes        | 24           |
# |    fps             | 20           |
# |    time_elapsed    | 237          |
# |    total timesteps | 4824         |
# | train/             |              |
# |    KL_loss         | 0.028329425  |
# |    actor_loss      | 164          |
# |    avg. z          | 0.0043874495 |
# |    avg. z var      | 0.8580452    |
# |    critic_loss     | 17.8         |
# |    ent_coef        | 0.00019      |
# |    ent_coef_loss   | 8.17         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 44823        |
# -------------------------------------
# 0.7380416663742875
# 2.32933742487199
# 2.84242003814375
# 0.5649501966779733
# ------------------------------------
# | time/              |             |
# |    episodes        | 28          |
# |    fps             | 20          |
# |    time_elapsed    | 275         |
# |    total timesteps | 5628        |
# | train/             |             |
# |    KL_loss         | 0.02629074  |
# |    actor_loss      | 163         |
# |    avg. z          | 0.042662952 |
# |    avg. z var      | 0.8833044   |
# |    critic_loss     | 57.5        |
# |    ent_coef        | 0.000238    |
# |    ent_coef_loss   | -1.98       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 45627       |
# ------------------------------------
# 2.8562139350255222
# 2.9235099391135497
# 1.7945559542389482
# 1.7745771870033273
# ------------------------------------
# | time/              |             |
# |    episodes        | 32          |
# |    fps             | 20          |
# |    time_elapsed    | 316         |
# |    total timesteps | 6432        |
# | train/             |             |
# |    KL_loss         | 0.009932879 |
# |    actor_loss      | 162         |
# |    avg. z          | 0.018989306 |
# |    avg. z var      | 0.9230088   |
# |    critic_loss     | 97.5        |
# |    ent_coef        | 0.000315    |
# |    ent_coef_loss   | 15.3        |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 46431       |
# ------------------------------------
# 0.7320997139394567
# 0.9954132603619548
# 1.3087443920495168
# 1.3006016428414324
# -------------------------------------
# | time/              |              |
# |    episodes        | 36           |
# |    fps             | 20           |
# |    time_elapsed    | 355          |
# |    total timesteps | 7236         |
# | train/             |              |
# |    KL_loss         | 0.03265036   |
# |    actor_loss      | 161          |
# |    avg. z          | -0.026031703 |
# |    avg. z var      | 0.85743463   |
# |    critic_loss     | 29           |
# |    ent_coef        | 0.000417     |
# |    ent_coef_loss   | 15.4         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 47235        |
# -------------------------------------
# 0.9783443946105542
# 0.14819131371612682
# 2.5789256412592847
# 2.37616428801651
# -------------------------------------
# | time/              |              |
# |    episodes        | 40           |
# |    fps             | 20           |
# |    time_elapsed    | 394          |
# |    total timesteps | 8040         |
# | train/             |              |
# |    KL_loss         | 0.019287549  |
# |    actor_loss      | 163          |
# |    avg. z          | -0.008930844 |
# |    avg. z var      | 0.9118918    |
# |    critic_loss     | 13.4         |
# |    ent_coef        | 0.000524     |
# |    ent_coef_loss   | 12.9         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 48039        |
# -------------------------------------
# 1.5568427059583314
# 0.6583127883511608
# 1.942839406961733
# 2.4325003907130585
# -------------------------------------
# | time/              |              |
# |    episodes        | 44           |
# |    fps             | 20           |
# |    time_elapsed    | 435          |
# |    total timesteps | 8844         |
# | train/             |              |
# |    KL_loss         | 0.0865089    |
# |    actor_loss      | 163          |
# |    avg. z          | -0.011307662 |
# |    avg. z var      | 0.7626052    |
# |    critic_loss     | 56           |
# |    ent_coef        | 0.000688     |
# |    ent_coef_loss   | 24.9         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 48843        |
# -------------------------------------
# 1.1278130110379934
# 0.4750838956777549
# 2.232864713772843
# 1.7791612581490865
# ------------------------------------
# | time/              |             |
# |    episodes        | 48          |
# |    fps             | 20          |
# |    time_elapsed    | 476         |
# |    total timesteps | 9648        |
# | train/             |             |
# |    KL_loss         | 0.033076823 |
# |    actor_loss      | 163         |
# |    avg. z          | 0.046958268 |
# |    avg. z var      | 0.8599888   |
# |    critic_loss     | 83          |
# |    ent_coef        | 0.000884    |
# |    ent_coef_loss   | 16.1        |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 49647       |
# ------------------------------------
# 0.3255127143808766
# 0.6887144931642402
# 1.25966306980056
# 2.8140451165101474
# ------------------------------------
# | time/              |             |
# |    episodes        | 52          |
# |    fps             | 20          |
# |    time_elapsed    | 517         |
# |    total timesteps | 10452       |
# | train/             |             |
# |    KL_loss         | 0.10565266  |
# |    actor_loss      | 161         |
# |    avg. z          | 0.013811591 |
# |    avg. z var      | 0.73841953  |
# |    critic_loss     | 15.3        |
# |    ent_coef        | 0.00111     |
# |    ent_coef_loss   | 15          |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 50451       |
# ------------------------------------
# 2.05092267811535
# 0.12193552109517647
# 0.5084395370794896
# 1.559995311739493
# ------------------------------------
# | time/              |             |
# |    episodes        | 56          |
# |    fps             | 20          |
# |    time_elapsed    | 561         |
# |    total timesteps | 11256       |
# | train/             |             |
# |    KL_loss         | 0.01632579  |
# |    actor_loss      | 160         |
# |    avg. z          | 0.031578466 |
# |    avg. z var      | 0.93009484  |
# |    critic_loss     | 47.1        |
# |    ent_coef        | 0.00145     |
# |    ent_coef_loss   | 14.4        |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 51255       |
# ------------------------------------
# 2.3026872042568374
# 0.7677753951492319
# 1.443429637521889
# 0.30291346820908327
# -------------------------------------
# | time/              |              |
# |    episodes        | 60           |
# |    fps             | 20           |
# |    time_elapsed    | 600          |
# |    total timesteps | 12060        |
# | train/             |              |
# |    KL_loss         | 0.01787899   |
# |    actor_loss      | 161          |
# |    avg. z          | -0.009125537 |
# |    avg. z var      | 0.8885461    |
# |    critic_loss     | 85           |
# |    ent_coef        | 0.00185      |
# |    ent_coef_loss   | 14.9         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 52059        |
# -------------------------------------
# 2.8623520172111654
# 0.08734375233300695
# 2.1672506076228304
# 1.5178814437347663
# ------------------------------------
# | time/              |             |
# |    episodes        | 64          |
# |    fps             | 20          |
# |    time_elapsed    | 640         |
# |    total timesteps | 12864       |
# | train/             |             |
# |    KL_loss         | 0.012077013 |
# |    actor_loss      | 159         |
# |    avg. z          | 0.04538952  |
# |    avg. z var      | 0.94233835  |
# |    critic_loss     | 11.1        |
# |    ent_coef        | 0.00232     |
# |    ent_coef_loss   | 9.41        |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 52863       |
# ...
# |    avg. z var      | 0.8976549     |
# |    critic_loss     | 48.6          |
# |    ent_coef        | 0.0416        |
# |    ent_coef_loss   | 1.17          |
# |    learning_rate   | 0.0003        |
# |    n_updates       | 384823        |
# --------------------------------------
# 0.7942052021927617
# 2.7183392390296537
# 1.7897087981498037
# 1.5312538617803795
# ------------------------------------
# | time/              |             |
# |    episodes        | 28          |
# |    fps             | 16          |
# |    time_elapsed    | 338         |
# |    total timesteps | 5628        |
# | train/             |             |
# |    KL_loss         | 0.02541884  |
# |    actor_loss      | 126         |
# |    avg. z          | 0.042542227 |
# |    avg. z var      | 0.9649065   |
# |    critic_loss     | 38.7        |
# |    ent_coef        | 0.0464      |
# |    ent_coef_loss   | 2.45        |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 385627      |
# ------------------------------------
# 0.8213098631403036
# 1.0453368376543324
# 1.552030972835855
# 1.5937609805117465
# ------------------------------------
# | time/              |             |
# |    episodes        | 32          |
# |    fps             | 16          |
# |    time_elapsed    | 386         |
# |    total timesteps | 6432        |
# | train/             |             |
# |    KL_loss         | 0.008472826 |
# |    actor_loss      | 126         |
# |    avg. z          | 0.019201133 |
# |    avg. z var      | 0.9305557   |
# |    critic_loss     | 62.1        |
# |    ent_coef        | 0.0478      |
# |    ent_coef_loss   | -1.04       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 386431      |
# ------------------------------------
# 2.0121437275631373
# 0.20416988747467957
# 1.433432267078104
# 1.6730016517584172
# ------------------------------------
# | time/              |             |
# |    episodes        | 36          |
# |    fps             | 16          |
# |    time_elapsed    | 430         |
# |    total timesteps | 7236        |
# | train/             |             |
# |    KL_loss         | 0.011435222 |
# |    actor_loss      | 129         |
# |    avg. z          | -0.0351274  |
# |    avg. z var      | 0.92581165  |
# |    critic_loss     | 8.13        |
# |    ent_coef        | 0.0451      |
# |    ent_coef_loss   | 1.26        |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 387235      |
# ------------------------------------
# 0.06867961640370124
# 2.7058911918602795
# 0.40647443295288377
# 2.6415389972284222
# --------------------------------------
# | time/              |               |
# |    episodes        | 40            |
# |    fps             | 16            |
# |    time_elapsed    | 474           |
# |    total timesteps | 8040          |
# | train/             |               |
# |    KL_loss         | 0.006326612   |
# |    actor_loss      | 130           |
# |    avg. z          | -0.0005798711 |
# |    avg. z var      | 0.939247      |
# |    critic_loss     | 32.1          |
# |    ent_coef        | 0.0417        |
# |    ent_coef_loss   | -2.19         |
# |    learning_rate   | 0.0003        |
# |    n_updates       | 388039        |
# --------------------------------------
# 1.5832442144744334
# 1.4323036091022807
# 0.9160055597522996
# 0.8442221658122376
# -------------------------------------
# | time/              |              |
# |    episodes        | 44           |
# |    fps             | 17           |
# |    time_elapsed    | 520          |
# |    total timesteps | 8844         |
# | train/             |              |
# |    KL_loss         | 0.010797542  |
# |    actor_loss      | 132          |
# |    avg. z          | -0.008910073 |
# |    avg. z var      | 0.9219489    |
# |    critic_loss     | 18.4         |
# |    ent_coef        | 0.0419       |
# |    ent_coef_loss   | 2.92         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 388843       |
# -------------------------------------
# 1.3557597993738306
# 1.3684224610540785
# 1.6426785879262662
# 0.7674639100078973
# ------------------------------------
# | time/              |             |
# |    episodes        | 48          |
# |    fps             | 17          |
# |    time_elapsed    | 565         |
# |    total timesteps | 9648        |
# | train/             |             |
# |    KL_loss         | 0.032549724 |
# |    actor_loss      | 128         |
# |    avg. z          | 0.02338727  |
# |    avg. z var      | 0.87252647  |
# |    critic_loss     | 105         |
# |    ent_coef        | 0.0421      |
# |    ent_coef_loss   | 2.17        |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 389647      |
# ------------------------------------
# 0.5648022476755724
# 2.5714303785482104
# 0.2030575897198149
# 1.268727622498579
# --------------------------------------
# | time/              |               |
# |    episodes        | 52            |
# |    fps             | 17            |
# |    time_elapsed    | 613           |
# |    total timesteps | 10452         |
# | train/             |               |
# |    KL_loss         | 0.010170944   |
# |    actor_loss      | 126           |
# |    avg. z          | -0.0055289213 |
# |    avg. z var      | 0.91548073    |
# |    critic_loss     | 7.72          |
# |    ent_coef        | 0.0444        |
# |    ent_coef_loss   | 1.04          |
# |    learning_rate   | 0.0003        |
# |    n_updates       | 390451        |
# --------------------------------------
# 1.6327293853004596
# 0.42948018445022695
# 1.2461488020534799
# 0.7610960147131339
# ------------------------------------
# | time/              |             |
# |    episodes        | 56          |
# |    fps             | 17          |
# |    time_elapsed    | 659         |
# |    total timesteps | 11256       |
# | train/             |             |
# |    KL_loss         | 0.008436836 |
# |    actor_loss      | 128         |
# |    avg. z          | 0.002420151 |
# |    avg. z var      | 0.92863977  |
# |    critic_loss     | 20.7        |
# |    ent_coef        | 0.0431      |
# |    ent_coef_loss   | -1.09       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 391255      |
# ------------------------------------
# 2.546264970244855
# 1.54469284142293
# 1.6568452936210625
# 1.1514303430992365
# ------------------------------------
# | time/              |             |
# |    episodes        | 60          |
# |    fps             | 17          |
# |    time_elapsed    | 704         |
# |    total timesteps | 12060       |
# | train/             |             |
# |    KL_loss         | 0.015187725 |
# |    actor_loss      | 126         |
# |    avg. z          | 0.016415512 |
# |    avg. z var      | 0.90189207  |
# |    critic_loss     | 5.3         |
# |    ent_coef        | 0.0404      |
# |    ent_coef_loss   | -1.14       |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 392059      |
# ------------------------------------
# 1.260548980024201
# 2.421398575223253
# 1.9243323356993782
# 1.090680921205645
# -------------------------------------
# | time/              |              |
# |    episodes        | 64           |
# |    fps             | 17           |
# |    time_elapsed    | 751          |
# |    total timesteps | 12864        |
# | train/             |              |
# |    KL_loss         | 0.005773604  |
# |    actor_loss      | 130          |
# |    avg. z          | -0.009899775 |
# |    avg. z var      | 0.93645555   |
# |    critic_loss     | 103          |
# |    ent_coef        | 0.0425       |
# |    ent_coef_loss   | 0.5          |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 392863       |
# -------------------------------------
# 2.8201592386329457
# 1.7649684585311363
# 2.0165014065286577
# 0.4862543352139882
# -------------------------------------
# | time/              |              |
# |    episodes        | 68           |
# |    fps             | 17           |
# |    time_elapsed    | 794          |
# |    total timesteps | 13668        |
# | train/             |              |
# |    KL_loss         | 0.009044539  |
# |    actor_loss      | 130          |
# |    avg. z          | -0.020521522 |
# |    avg. z var      | 0.9449832    |
# |    critic_loss     | 61.5         |
# |    ent_coef        | 0.0428       |
# |    ent_coef_loss   | -2.27        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 393667       |
# -------------------------------------
# 0.7182134351072635
# 0.4207769273935009
# 2.2788601508753565
# 1.4678375261193577
# -------------------------------------
# | time/              |              |
# |    episodes        | 72           |
# |    fps             | 17           |
# |    time_elapsed    | 839          |
# |    total timesteps | 14472        |
# | train/             |              |
# |    KL_loss         | 0.01279046   |
# |    actor_loss      | 126          |
# |    avg. z          | -0.009056963 |
# |    avg. z var      | 0.90689814   |
# |    critic_loss     | 90.3         |
# |    ent_coef        | 0.0423       |
# |    ent_coef_loss   | 0.565        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 394471       |
# -------------------------------------
# 0.8481385969218848
# 2.279157236973146
# 0.8990083365532183
# 1.931589963514054
# ------------------------------------
# | time/              |             |
# |    episodes        | 76          |
# |    fps             | 17          |
# |    time_elapsed    | 886         |
# |    total timesteps | 15276       |
# | train/             |             |
# |    KL_loss         | 0.007840995 |
# |    actor_loss      | 127         |
# |    avg. z          | 0.009171991 |
# |    avg. z var      | 0.9253272   |
# |    critic_loss     | 42.5        |
# |    ent_coef        | 0.0477      |
# |    ent_coef_loss   | -0.389      |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 395275      |
# ------------------------------------
# 1.556477844012568
# 1.9010133186888336
# 1.9797402320238429
# 0.7654690555716479
# -------------------------------------
# | time/              |              |
# |    episodes        | 80           |
# |    fps             | 17           |
# |    time_elapsed    | 930          |
# |    total timesteps | 16080        |
# | train/             |              |
# |    KL_loss         | 0.017661903  |
# |    actor_loss      | 128          |
# |    avg. z          | -0.016472682 |
# |    avg. z var      | 0.9022875    |
# |    critic_loss     | 61.2         |
# |    ent_coef        | 0.0411       |
# |    ent_coef_loss   | -1.24        |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 396079       |
# -------------------------------------
# 1.7685919199818558
# 0.3645818291519033
# 0.1489187115771723
# 0.585887926851249
# -------------------------------------
# | time/              |              |
# |    episodes        | 84           |
# |    fps             | 17           |
# |    time_elapsed    | 975          |
# |    total timesteps | 16884        |
# | train/             |              |
# |    KL_loss         | 0.024557963  |
# |    actor_loss      | 126          |
# |    avg. z          | 0.0014025003 |
# |    avg. z var      | 0.89675504   |
# |    critic_loss     | 32.1         |
# |    ent_coef        | 0.0371       |
# |    ent_coef_loss   | 1.51         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 396883       |
# -------------------------------------
# 2.1841562077846337
# 2.339956610617878
# 2.721505178351063
# 0.5395994910879344
# -------------------------------------
# | time/              |              |
# |    episodes        | 88           |
# |    fps             | 17           |
# |    time_elapsed    | 1021         |
# |    total timesteps | 17688        |
# | train/             |              |
# |    KL_loss         | 0.013773624  |
# |    actor_loss      | 127          |
# |    avg. z          | -0.020103851 |
# |    avg. z var      | 0.9102701    |
# |    critic_loss     | 6.37         |
# |    ent_coef        | 0.0411       |
# |    ent_coef_loss   | 1.71         |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 397687       |
# -------------------------------------
# 2.055968422891607
# 0.978786534049994
# 0.6392207616761135
# 1.3784390991717625
# ------------------------------------
# | time/              |             |
# |    episodes        | 92          |
# |    fps             | 17          |
# |    time_elapsed    | 1070        |
# |    total timesteps | 18492       |
# | train/             |             |
# |    KL_loss         | 0.025989216 |
# |    actor_loss      | 128         |
# |    avg. z          | 0.032899987 |
# |    avg. z var      | 0.88811576  |
# |    critic_loss     | 7.59        |
# |    ent_coef        | 0.0458      |
# |    ent_coef_loss   | 1.03        |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 398491      |
# ------------------------------------
# 0.1972681176559008
# 1.3084298280008921
# 2.776179457754706
# 2.6907253830206885
# ------------------------------------
# | time/              |             |
# |    episodes        | 96          |
# |    fps             | 17          |
# |    time_elapsed    | 1125        |
# |    total timesteps | 19296       |
# | train/             |             |
# |    KL_loss         | 0.01660642  |
# |    actor_loss      | 128         |
# |    avg. z          | -0.03806121 |
# |    avg. z var      | 0.9227108   |
# |    critic_loss     | 78.4        |
# |    ent_coef        | 0.041       |
# |    ent_coef_loss   | -0.973      |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 399295      |
# ------------------------------------
# 1.7481982576345574
# 1.6765747838812568
# 1.2594002956766226
# 1.416290895731855
# 0.4685447330381134
# 1.7504130586891073
# 2.8074753241289656
# 1.6411090867252862
# 1.1537872821683495
# 1.5531014046651026
# 1.2261406915443842
# 0.21405314746132897
# 0.7387644843568029
# 2.181323367860305
# 2.744207167177596
# 2.054149644439146
# 2.1477055854218765
# 2.489594154968482
# 0.6981320191550524
# 1.2764349835714368
# 0.797991793128119
# 2.391763741226188
# 0.3427074555108709
# 1.1792724885437769
# 1.3370335327712382
# 1.3261996112100076
# 0.5227629371994508
# 1.0934823649425942
# 0.09769965290083549
# 0.516838223469776
# 1.798810444816536
# 0.5289944997152404
# 2.9736031905018017
# epoch: 19
# meta_reward =  [-318.68103072624336, -326.54882258410385, -304.515222570106, -287.7606776442862, -244.79878016444496, -278.13833711494055, -306.5244451324483, -294.9255042027479, -275.90134690340443, -265.822057415149, -277.37067222252296, -306.931355699618, -286.0593583835666, -272.30829256723484, -275.8520396258373, -276.67852904821626, -264.5455010634697, -260.21680545878746, -266.0523503735618, -245.57357063826615]
# meta_std =  [147.71888857471905, 175.5345762966199, 168.45162860360475, 131.39012944194258, 85.41128004439615, 97.7960981448435, 113.99162149654869, 109.01791181712932, 103.87970018059504, 98.83209265125262, 81.40978146794853, 106.1695259584096, 101.42056077059966, 80.09528878180224, 86.5755221846073, 84.1676508265066, 86.18641956420021, 79.03167378452609, 71.92209431502778, 68.08882040882327]
# 1.0177176325309638
# 0.22041280181741818
# 2.836997830435745
# 0.4107533739140439
# ------------------------------------
# | time/              |             |
# |    episodes        | 4           |
# |    fps             | 12          |
# |    time_elapsed    | 62          |
# |    total timesteps | 804         |
# | train/             |             |
# |    KL_loss         | 0.02053082  |
# |    actor_loss      | 126         |
# |    avg. z          | 0.031597942 |
# |    avg. z var      | 0.9199723   |
# |    critic_loss     | 15.1        |
# |    ent_coef        | 0.0434      |
# |    ent_coef_loss   | -2.1        |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 400803      |
# ------------------------------------
# 1.6291529444049786
# 2.0256825650386365
# 0.4506460136795869
# 1.2993982075092976
# ------------------------------------
# | time/              |             |
# |    episodes        | 8           |
# |    fps             | 12          |
# |    time_elapsed    | 123         |
# |    total timesteps | 1608        |
# | train/             |             |
# |    KL_loss         | 0.004555216 |
# |    actor_loss      | 127         |
# |    avg. z          | 0.002644246 |
# |    avg. z var      | 0.94270456  |
# |    critic_loss     | 18.4        |
# |    ent_coef        | 0.0422      |
# |    ent_coef_loss   | 0.0459      |
# |    learning_rate   | 0.0003      |
# |    n_updates       | 401607      |
# ------------------------------------

# %%
a =

# %%
# imports
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates
import numpy as np

fig, ax = plt.subplots(1)
ax.set_facecolor('white')

# Define upper and lower bounds for shaded variation
lower_bound_meta = (np.asarray(meta_reward) - np.asarray(meta_std))
upper_bound_meta = (np.asarray(meta_reward) + np.asarray(meta_std))

print(lower_bound_meta)

lower_bound_vanilla = (np.asarray(vanilla_reward) - np.asarray(vanilla_std))
upper_bound_vanilla =  (np.asarray(vanilla_reward) + np.asarray(vanilla_std))

fig, ax = plt.subplots(1)
ax.set_facecolor('white')

x = [a*10000 for a in range(len(meta_reward))]

ax.plot(x, meta_reward, lw=0.9, color = 'blue')
#ax.plot(x, vanilla_reward, lw=0.9, color = 'red')

# Variation and shaded area
ax.fill_between(x, lower_bound_meta, upper_bound_meta, facecolor='blue', alpha=0.3)
#ax.fill_between(x, lower_bound_vanilla, upper_bound_vanilla, facecolor='red', alpha=0.3)
fig = ax.get_figure()


fig.show()

# %%
x

# %%
vanilla_reward

# %%
env =FooEnv()# gym.make('LunarLanderContinuous-v2')#
#model = SAC('MlpPolicy', env, verbose=1,policy_kwargs=dict(net_arch=[300, 300, 300]))#,learning_rate=0.0006)
model = mSAC('MlpPolicy', env, verbose=1,policy_kwargs=dict(net_arch=[300, 300, 300], latent_dim = 7, hidden_sizes=[300,300,300]))#,learning_rate=0.0006)
#model = PPO('MlpPolicy', env, verbose=1,policy_kwargs=dict(net_arch=[300, 300, 300]))#,learning_rate=0.0006)

print('-Start-')
n_eval = 1

mean_reward_before, std_reward_before = evaluate_meta_policy(model, env, n_eval_episodes=n_eval)
print('Start Learning')
model.learn(total_timesteps=2500)#, eval_freq=100, n_eval_episodes=5)

mean_reward, std_reward = evaluate_meta_policy(model, env, n_eval_episodes=n_eval)
print(f"mean_reward, before training:{mean_reward_before:.2f} +/- {std_reward_before:.2f}")

print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
